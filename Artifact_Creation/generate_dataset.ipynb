# %%
from damage_generator.scans import load_scans, load_all_synthetic_images
from damage_generator.generate_masks import create_random_mask, create_random_mask_with_transparency
import os
import argparse
import cv2 as cv
import uuid
import numpy as np
from matplotlib import pyplot as plt
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ##### **Default parameters**

# %%
height = 1024
width = 1024

synthetic = False
rescale = True
binarized = True
verbose = False
uniform = False

# %% [markdown]
# 1. Extract real artifacts from annotations

# %%
scans_path = "/scans/"
synthetic_path = "/synthetic/"

abs_path = os.path.abspath("")
scans_path = abs_path + scans_path
synthetic_path = os.path.dirname(os.path.normpath(abs_path))+ synthetic_path
df_artifacts = load_scans(scans_path, verbose=verbose)


### Optionally use synthetic artifacts ###
if synthetic:
    df_synthetic = df_synthetic_articats = load_all_synthetic_images(synthetic_path, verbose=verbose)
else: df_synthetic = None

df_per_patch_counts = df_artifacts.groupby(['Quandrant', 'Type']).size().to_frame('Counts').reset_index()
# Out:
# Loading dust scan  /home/priubrogent/tfg/FilmDamageSimulator/scans/Scan (1).jpg
# Loading dust scan  /home/priubrogent/tfg/FilmDamageSimulator/scans/Scan (2).jpg
# Loading dust scan  /home/priubrogent/tfg/FilmDamageSimulator/scans/Scan (3).jpg
# Loading dust scan  /home/priubrogent/tfg/FilmDamageSimulator/scans/Scan (4).jpg
# Loading dust scan  /home/priubrogent/tfg/FilmDamageSimulator/scans/Scan (5).jpg
# Loading dust scan  /home/priubrogent/tfg/FilmDamageSimulator/scans/Scan (6).jpg
# Loading dust scan  /home/priubrogent/tfg/FilmDamageSimulator/scans/Scan (7).jpg
# Loading dust scan  /home/priubrogent/tfg/FilmDamageSimulator/scans/Scan (8).jpg
# Loading dust scan  /home/priubrogent/tfg/FilmDamageSimulator/scans/Scan (9).jpg
# Loading dust scan  /home/priubrogent/tfg/FilmDamageSimulator/scans/Scan (10).jpg

# %% [markdown]
# 1.1 Load test image

# %%
test_images = os.listdir("./test_images")

test_image = cv.imread("./test_images/" + test_images[0])

height, width, _ = test_image.shape

# %%
import cv2

# %%
def create_dirty_images(images_dir, output_folder):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    if not os.path.exists(output_folder+"train"):
        os.makedirs(output_folder+"train")
    if not os.path.exists(output_folder+"train_mask"):
        os.makedirs(output_folder+"train_mask")    
    images = os.listdir(images_dir)
    for image in images:
        original_img = cv.imread(images_dir + image)
        height, width, _ = original_img.shape
        mask, binary_mask, perlin_noise = create_random_mask((height, width), df_artifacts, df_synthetic, df_per_patch_counts, use_synthetic=synthetic, rescale=rescale, uniform_sample=uniform, verbose=verbose)
        mask = mask.astype(np.float32) / 255.0  # White = 1, Black = 0 (dirt areas)
        plt.imshow(binary_mask, cmap='gray')
        darkening_mask_colored = cv2.cvtColor(mask, cv2.COLOR_GRAY2BGR)
        dirty_image = (original_img * darkening_mask_colored).astype(np.uint8)

        cv.imwrite(output_folder+"train/"+image, dirty_image,)
        cv.imwrite(output_folder+"train_mask/"+image+"_mask.png", binary_mask)

# %%
img_dirty = (img * darkening_mask_colored).astype(np.uint8)
img_dirty_resized = resize(img_dirty, (self.height, self.width), mode='reflect', anti_aliasing=True)

mask_resized = resize(mask, (self.height, self.width), mode='reflect', anti_aliasing=True)
mask_resized_binary = np.where(mask_resized > 0.9, 1, 0)
# mask_resized = np.where(mask_resized > 0.9, 1, 0)
# Convert skimage mask to uint8 if needed
mask_resized_uint8 = img_as_ubyte(mask_resized > 0)  # Ensure binary mask is uint8
 if img_dirty.ndim == 3:  # Check if it's a color image
                blurred_img = np.stack([gaussian(img_dirty_resized[..., i], sigma=self.sigma) for i in range(img_dirty_resized.shape[-1])], axis=-1)
            else:
                blurred_img = gaussian(img_dirty, sigma=5)  # Grayscale case

# Convert back to uint8
            blurred_img = img_as_ubyte(blurred_img)
            # Step 3: Superimpose the blurred dirt spots only where mask_resized was
            img_dirty_final = img_dirty_resized.copy()
            img_dirty_final[mask_resized_uint8 > 0] = blurred_img[mask_resized_uint8 > 0]
            
            img_tensor = torch.tensor(img_dirty_final).permute(2, 0, 1).float()
            mask_tensor = torch.tensor(mask_resized_binary).unsqueeze(0).float()

# %%
import cv2

# %%
def create_dirty_images(images_dir, output_folder):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    if not os.path.exists(output_folder+"train"):
        os.makedirs(output_folder+"train")
    if not os.path.exists(output_folder+"train_mask"):
        os.makedirs(output_folder+"train_mask")
    if not os.path.exists(output_folder+"train_new_loader"):
        os.makedirs(output_folder+"train_new_loader")
    images = os.listdir(images_dir)
    for image in images:
        original_img = cv.imread(images_dir + image)
        height, width, _ = original_img.shape
        mask, binary_mask, perlin_noise = create_random_mask((height, width), df_artifacts, df_synthetic, df_per_patch_counts, use_synthetic=synthetic, rescale=rescale, uniform_sample=uniform, verbose=verbose)
        mask = mask.astype(np.float32) / 255.0  # White = 1, Black = 0 (dirt areas)
        # plt.imshow(mask)
        plt.imshow(binary_mask, cmap='gray')
        darkening_mask_colored = cv2.cvtColor(mask, cv2.COLOR_GRAY2BGR)
        dirty_image = (original_img * darkening_mask_colored).astype(np.uint8)
        blurred_img = np.stack([gaussian(dirty_image[..., i], sigma=1) for i in range(dirty_image.shape[-1])], axis=-1)
        blurred_img = img_as_ubyte(blurred_img)
        img_dirty_final = dirty_image.copy()
        img_dirty_final[binary_mask < 230] = blurred_img[binary_mask < 230]
        cv.imwrite(output_folder+"train/"+image, dirty_image,)
        cv.imwrite(output_folder+"train_mask/"+image+"_mask.png", binary_mask)
        cv.imwrite(output_folder+"train_new_loader/"+image, img_dirty_final)
        img_dirty_final = cv2.cvtColor(img_dirty_final, cv2.COLOR_BGR2RGB)

# %%
create_dirty_images("./test/train/", "./test/nou_test_dataset/")

# %% [markdown]
# 2. Generate mask of target size

# %%
mask, binary_mask, perlin_noise = create_random_mask((height, width), df_artifacts, df_synthetic, df_per_patch_counts, use_synthetic=synthetic, rescale=rescale, uniform_sample=uniform, verbose=verbose)
# Out:
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]

# %%
f, axarr = plt.subplots(1, 2, figsize=(10, 5))

axarr[0].imshow(mask, cmap='gray')
axarr[1].imshow(binary_mask, cmap='gray')

# %%
rgb_mask = cv.cvtColor(mask, cv.COLOR_GRAY2RGB)

non_white_mask = np.any(rgb_mask < [200, 200, 200], axis=-1)

non_white_mask.shape
plt.imshow(non_white_mask, cmap="gray")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 rgb_mask = cv.cvtColor(mask, cv.COLOR_GRAY2RGB)
# ----> 3 non_white_mask = np.any(rgb_mask < [200, 200, 200], axis=-1)
#       5 non_white_mask.shape
#       6 plt.imshow(non_white_mask, cmap="gray")
#
# NameError: name 'np' is not defined

# %%
# turn any non white pixels to black on rgb_mask
rgb_mask[non_white_mask] = [0, 0, 0]
test_image_dirty = test_image.copy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 # turn any non white pixels to black on rgb_mask
# ----> 2 rgb_mask[non_white_mask] = [0, 0, 0]
#       3 test_image_dirty = test_image.copy()
#
# NameError: name 'non_white_mask' is not defined

# %%
test_image_dirty[non_white_mask] = rgb_mask[non_white_mask]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 test_image_dirty[non_white_mask] = rgb_mask[non_white_mask]
#
# NameError: name 'non_white_mask' is not defined

# %%
plt.imshow(test_image_dirty)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 plt.imshow(test_image_dirty)
#
# NameError: name 'test_image_dirty' is not defined

# %%
images_dir = "./test_images/"
images = os.listdir(images_dir)
for image in images:

    original_img = cv.imread(images_dir + image)
    # rgb_image = cv.cvtColor(original_img, cv.COLOR_BGR2RGB)
    mask, binary_mask, perlin_noise = create_random_mask((height, width), df_artifacts, df_synthetic, df_per_patch_counts, use_synthetic=synthetic, rescale=rescale, uniform_sample=uniform, verbose=verbose)
    rgb_mask = cv.cvtColor(mask, cv.COLOR_GRAY2RGB)

    non_white_mask = np.any(rgb_mask < [200, 200, 200], axis=-1)
    rgb_mask[non_white_mask] = [0, 0, 0]
    
    dirty_image = original_img.copy()

    dirty_image[non_white_mask] = rgb_mask[non_white_mask]

    # save dirty_image to ./dirty/
    cv.imwrite("./dirty/"+image, dirty_image,)
    cv.imwrite("./dirty/mask/"+image+"_mask.png", binary_mask)
# Out:
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\sample.py:46: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df_sort = df.iloc[(dust_areas-i).abs().argsort()[:15]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 7
#       5 original_img = cv.imread(images_dir + image)
#       6 # rgb_image = cv.cvtColor(original_img, cv.COLOR_BGR2RGB)
# ----> 7 mask, binary_mask, perlin_noise = create_random_mask((height, width), df_artifacts, df_synthetic, df_per_patch_counts, use_synthetic=synthetic, rescale=rescale, uniform_sample=uniform, verbose=verbose)
#       8 rgb_mask = cv.cvtColor(mask, cv.COLOR_GRAY2RGB)
#      10 non_white_mask = np.any(rgb_mask < [200, 200, 200], axis=-1)
#
# File c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\generate_masks.py:230, in create_random_mask(target_size, df, df_synthetic, df_counts, use_synthetic, min_artifacts, max_artifacts, rescale, uniform_sample, verbose)
#     228 for scratch_length in extra_scratches_lengths:
#     229     try:
# --> 230         scratch = line_scratch(scratch_length)
#     231         scratch = skimage_tf.rotate(scratch, angle=random_angle_scratches, resize=True, preserve_range=True)
#     233         if horizontal > 0.5 : scratch = np.rot90(scratch)
#
# File c:\Users\polri\Documents\00_Uni\4rt Curs - 2024_25\TreballFiGrau\FilmDamageSimulator\damage_generator\generate_masks.py:65, in line_scratch(length)
#      63 noise_scale = np.random.randint(1, 4, size=1, dtype=int)[0].item()
#      64 perlin_noise = generate_perlin_noise_2d((length_pot, length_pot), (2**noise_scale, 2**noise_scale))
# ---> 65 normalised_noise = (perlin_noise - np.min(perlin_noise))/np.ptp(perlin_noise)
#      66 slice_fade = np.random.randint(low=0, high=length-20, size=1, dtype=int)[0]
#      67 fade = increase_contrast(normalised_noise)[0:length.item(), slice_fade.item():slice_fade.item()+20]
#
# File c:\Users\polri\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\core\fromnumeric.py:2684, in ptp(a, axis, out, keepdims)
#    2682     else:
#    2683         return ptp(axis=axis, out=out, **kwargs)
# -> 2684 return _methods._ptp(a, axis=axis, out=out, **kwargs)
#
# File c:\Users\polri\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\core\_methods.py:220, in _ptp(a, axis, out, keepdims)
#     218 def _ptp(a, axis=None, out=None, keepdims=False):
#     219     return um.subtract(
# --> 220         umr_maximum(a, axis, None, out, keepdims),
#     221         umr_minimum(a, axis, None, None, keepdims),
#     222         out
#     223     )
#
# KeyboardInterrupt:

# %%
create_dirty_images("red_river_frames/", "./dirty_red_river/")
# Out:
# frame0001.png
# frame0002.png
# frame0003.png
# frame0004.png
# frame0005.png
# frame0006.png
# frame0007.png
# frame0008.png
# frame0009.png
# frame0010.png
# frame0011.png
# frame0012.png
# frame0013.png
# frame0014.png
# frame0015.png
# frame0016.png
# frame0017.png
# frame0018.png
# frame0019.png
# frame0020.png
# frame0021.png
# frame0022.png
# frame0023.png
# frame0024.png
# frame0025.png
# frame0026.png
# frame0027.png
# frame0028.png
# frame0029.png
# frame0030.png
# frame0031.png
# frame0032.png
# frame0033.png
# frame0034.png
# frame0035.png
# frame0036.png
# frame0037.png
# frame0038.png
# frame0039.png
# frame0040.png
# frame0041.png
# frame0042.png
# frame0043.png
# frame0044.png
# frame0045.png
# frame0046.png
# frame0047.png
# frame0048.png
# frame0049.png
# frame0050.png
# frame0051.png
# frame0052.png
# frame0053.png
# frame0054.png
# frame0055.png
# frame0056.png
# frame0057.png
# frame0058.png
# frame0059.png
# frame0060.png
# frame0061.png
# frame0062.png
# frame0063.png
# frame0064.png
# frame0065.png
# frame0066.png
# frame0067.png
# frame0068.png
# frame0069.png
# frame0070.png
# frame0071.png
# frame0072.png
# frame0073.png
# frame0074.png
# frame0075.png
# frame0076.png
# frame0077.png
# frame0078.png
# frame0079.png
# frame0080.png
# frame0081.png
# frame0082.png
# frame0083.png
# frame0084.png
# frame0085.png
# frame0086.png
# frame0087.png
# frame0088.png
# frame0089.png
# frame0090.png
# frame0091.png
# frame0092.png
# frame0093.png
# frame0094.png
# frame0095.png
# frame0096.png
# frame0097.png
# frame0098.png
# frame0099.png
# frame0100.png
# frame0101.png
# frame0102.png
# frame0103.png
# frame0104.png
# frame0105.png
# frame0106.png
# frame0107.png
# frame0108.png
# frame0109.png
# frame0110.png
# frame0111.png
# frame0112.png
# frame0113.png
# frame0114.png
# frame0115.png
# frame0116.png
# frame0117.png
# frame0118.png
# frame0119.png
# frame0120.png
# frame0121.png
# frame0122.png
# frame0123.png
# frame0124.png
# frame0125.png
# frame0126.png
# frame0127.png
# frame0128.png
# frame0129.png
# frame0130.png
# frame0131.png
# frame0132.png
# frame0133.png
# frame0134.png
# frame0135.png
# frame0136.png
# frame0137.png
# frame0138.png
# frame0139.png
# frame0140.png
# frame0141.png
# frame0142.png
# frame0143.png
# frame0144.png
# frame0145.png
# frame0146.png
# frame0147.png
# frame0148.png
# frame0149.png
# frame0150.png
# frame0151.png
# frame0152.png
# frame0153.png
# frame0154.png
# frame0155.png
# frame0156.png
# frame0157.png
# frame0158.png
# frame0159.png
# frame0160.png
# frame0161.png
# frame0162.png
# frame0163.png
# frame0164.png
# frame0165.png
# frame0166.png
# frame0167.png
# frame0168.png
# frame0169.png
# frame0170.png
# frame0171.png
# frame0172.png
# frame0173.png
# frame0174.png
# frame0175.png
# frame0176.png
# frame0177.png
# frame0178.png
# frame0179.png
# frame0180.png
# frame0181.png
# frame0182.png
# frame0183.png
# frame0184.png
# frame0185.png
# frame0186.png
# frame0187.png
# frame0188.png
# frame0189.png
# frame0190.png
# frame0191.png
# frame0192.png
# frame0193.png
# frame0194.png
# frame0195.png
# frame0196.png
# frame0197.png
# frame0198.png
# frame0199.png
# frame0200.png
# frame0201.png
# frame0202.png
# frame0203.png
# frame0204.png
# frame0205.png
# frame0206.png
# frame0207.png
# frame0208.png
# frame0209.png
# frame0210.png
# frame0211.png
# frame0212.png
# frame0213.png
# frame0214.png
# frame0215.png
# frame0216.png
# frame0217.png
# frame0218.png
# frame0219.png
# frame0220.png
# frame0221.png
# frame0222.png
# frame0223.png
# frame0224.png
# frame0225.png
# frame0226.png
# frame0227.png
# frame0228.png
# frame0229.png
# frame0230.png
# frame0231.png
# frame0232.png
# frame0233.png
# frame0234.png
# frame0235.png
# frame0236.png
# frame0237.png
# frame0238.png
# frame0239.png
# frame0240.png

# %%
# Load the clean image and the dirt/scratch mask
clean_image = cv.imread("./red_river_frames/frame0023.png", cv.IMREAD_COLOR)
# mask = cv.imread("dirt_mask.jpg", cv.IMREAD_GRAYSCALE)  # Assume it's grayscale

height, width, _ = clean_image.shape


mask, binary_mask, perlin_noise = create_random_mask((height, width), df_artifacts, df_synthetic, df_per_patch_counts, use_synthetic=synthetic, rescale=rescale, uniform_sample=uniform, verbose=verbose)
        
inverted_mask = cv.bitwise_not(mask)

# Convert the grayscale mask to 3 channels
mask_colored = cv.cvtColor(inverted_mask, cv.COLOR_GRAY2BGR)

# Blend the dirt mask with the clean image
alpha = 0.6  # Adjust transparency (higher means stronger effect)
blended = cv.addWeighted(clean_image, 1, mask_colored, alpha, 0)

plt.imshow(cv.cvtColor(blended, cv.COLOR_BGR2RGB))

# %%
# Load the clean image and the dirt/scratch mask
clean_image = cv.imread("./red_river_frames/frame0023.png", cv.IMREAD_COLOR)
# mask = cv.imread("dirt_mask.jpg", cv.IMREAD_GRAYSCALE)  # Assume it's grayscale

height, width, _ = clean_image.shape
# mask, binary_mask, perlin_noise = create_random_mask((height, width), df_artifacts, df_synthetic, df_per_patch_counts, use_synthetic=synthetic, rescale=rescale, uniform_sample=uniform, verbose=verbose)
# change the mask, and binary mask to a 400x400 black in the middle
mask = np.zeros((height, width), dtype=np.uint8)
mask[300:800, 300:800] = 255
binary_mask = np.zeros((height, width), dtype=np.uint8)
binary_mask[300:800, 300:800] = 255


# Resize mask to match the clean image if necessary
mask = cv.resize(mask, (clean_image.shape[1], clean_image.shape[0]))

# Normalize mask to be in range [0, 1]
mask = mask.astype(np.float32) / 255.0  

# Convert mask to 3-channel
mask_colored = cv.cvtColor(mask, cv.COLOR_GRAY2BGR)

# Darken the image where the mask is present
damaged_image = (clean_image * (1 - mask_colored)).astype(np.uint8)

# %% [markdown]
# ### Solo test

# %%
import cv2
clean_image = cv.imread("./red_river_frames/frame0023.png", cv.IMREAD_COLOR)

# Load the clean image and dirt/scratch mask
mask, binary_mask, perlin_noise = create_random_mask((height, width), df_artifacts, df_synthetic, df_per_patch_counts, use_synthetic=synthetic, rescale=rescale, uniform_sample=uniform, verbose=verbose)


# Normalize the mask to range [0,1]
mask = mask.astype(np.float32) / 255.0  # White = 1, Black = 0 (dirt areas)

# Invert the mask so dirt areas become darkening factors
# darkening_mask = 1 - mask  # Now dirt is 1 (full effect), background is 0 (no effect)

# Convert to 3-channel for RGB multiplication
darkening_mask_colored = cv2.cvtColor(mask, cv2.COLOR_GRAY2BGR)
plt.imshow(cv2.cvtColor(darkening_mask_colored, cv2.COLOR_BGR2RGB))
# Apply the darkening effect
darkened_image = (clean_image * darkening_mask_colored).astype(np.uint8)


plt.imshow(cv2.cvtColor(darkened_image, cv2.COLOR_BGR2RGB))

# %% [markdown]
# #### Test function white square

# %%
def create_test_images(images_dir, output_folder):
    images = os.listdir(images_dir)
    for image in images:
        print(image)
        original_img = cv.imread(images_dir + image)
        height, width, _ = original_img.shape
        mask = np.zeros((height, width), dtype=np.uint8)
        mask[300:800, 300:800] = 255
        binary_mask = np.zeros((height, width), dtype=np.uint8)
        binary_mask[300:800, 300:800] = 255
        mask = mask.astype(np.float32) / 255.0  # White = 1, Black = 0 (dirt areas)
        # mask = cv2.bitwise_not(mask)
        mask_colored = cv.cvtColor(mask, cv.COLOR_GRAY2BGR)
        
        dirty_image = (original_img * (1 - mask_colored)).astype(np.uint8)

        cv.imwrite(output_folder+image, dirty_image,)
        cv.imwrite(output_folder+"mask/"+image+"_mask.png", binary_mask)

create_test_images("bueno_feo_malo/", "./out_bueno_feo_proves/")
# Out:
# leone_frame_0_0001.png
# leone_frame_0_0002.png
# leone_frame_0_0003.png
# leone_frame_0_0004.png
# leone_frame_0_0005.png
# leone_frame_0_0006.png
# leone_frame_0_0007.png
# leone_frame_0_0008.png
# leone_frame_0_0009.png
# leone_frame_0_0010.png
# leone_frame_0_0011.png
# leone_frame_0_0012.png
# leone_frame_0_0013.png
# leone_frame_0_0014.png
# leone_frame_0_0015.png
# leone_frame_0_0016.png
# leone_frame_0_0017.png
# leone_frame_0_0018.png
# leone_frame_0_0019.png
# leone_frame_0_0020.png
# leone_frame_0_0021.png
# leone_frame_0_0022.png
# leone_frame_0_0023.png
# leone_frame_0_0024.png
# leone_frame_0_0025.png
# leone_frame_0_0026.png
# leone_frame_0_0027.png
# leone_frame_0_0028.png
# leone_frame_0_0029.png
# leone_frame_0_0030.png
# leone_frame_0_0031.png
# leone_frame_0_0032.png
# leone_frame_0_0033.png
# leone_frame_0_0034.png
# leone_frame_0_0035.png
# leone_frame_0_0036.png
# leone_frame_0_0037.png
# leone_frame_0_0038.png
# leone_frame_0_0039.png
# leone_frame_0_0040.png
# leone_frame_0_0041.png
# leone_frame_0_0042.png
# leone_frame_0_0043.png
# leone_frame_0_0044.png
# leone_frame_0_0045.png
# leone_frame_0_0046.png
# leone_frame_0_0047.png
# leone_frame_0_0048.png
# leone_frame_1_0001.png
# leone_frame_1_0002.png
# leone_frame_1_0003.png
# leone_frame_1_0004.png
# leone_frame_1_0005.png
# leone_frame_1_0006.png
# leone_frame_1_0007.png
# leone_frame_1_0008.png
# leone_frame_1_0009.png
# leone_frame_1_0010.png
# leone_frame_1_0011.png
# leone_frame_1_0012.png
# leone_frame_1_0013.png
# leone_frame_1_0014.png
# leone_frame_1_0015.png
# leone_frame_1_0016.png
# leone_frame_1_0017.png
# leone_frame_1_0018.png
# leone_frame_1_0019.png
# leone_frame_1_0020.png
# leone_frame_1_0021.png
# leone_frame_1_0022.png
# leone_frame_1_0023.png
# leone_frame_1_0024.png
# leone_frame_1_0025.png
# leone_frame_1_0026.png
# leone_frame_1_0027.png
# leone_frame_1_0028.png
# leone_frame_1_0029.png
# leone_frame_1_0030.png
# leone_frame_1_0031.png
# leone_frame_1_0032.png
# leone_frame_1_0033.png
# leone_frame_1_0034.png
# leone_frame_1_0035.png
# leone_frame_1_0036.png
# leone_frame_1_0037.png
# leone_frame_1_0038.png
# leone_frame_1_0039.png
# leone_frame_1_0040.png
# leone_frame_1_0041.png
# leone_frame_1_0042.png
# leone_frame_1_0043.png
# leone_frame_1_0044.png
# leone_frame_1_0045.png
# leone_frame_1_0046.png
# leone_frame_1_0047.png
# leone_frame_1_0048.png
# leone_frame_2_0001.png
# leone_frame_2_0002.png
# leone_frame_2_0003.png
# leone_frame_2_0004.png
# leone_frame_2_0005.png
# leone_frame_2_0006.png
# leone_frame_2_0007.png
# leone_frame_2_0008.png
# leone_frame_2_0009.png
# leone_frame_2_0010.png
# leone_frame_2_0011.png
# leone_frame_2_0012.png
# leone_frame_2_0013.png
# leone_frame_2_0014.png
# leone_frame_2_0015.png
# leone_frame_2_0016.png
# leone_frame_2_0017.png
# leone_frame_2_0018.png
# leone_frame_2_0019.png
# leone_frame_2_0020.png
# leone_frame_2_0021.png
# leone_frame_2_0022.png
# leone_frame_2_0023.png
# leone_frame_2_0024.png
# leone_frame_2_0025.png
# leone_frame_2_0026.png
# leone_frame_2_0027.png
# leone_frame_2_0028.png
# leone_frame_2_0029.png
# leone_frame_2_0030.png
# leone_frame_2_0031.png
# leone_frame_2_0032.png
# leone_frame_2_0033.png
# leone_frame_2_0034.png
# leone_frame_2_0035.png
# leone_frame_2_0036.png
# leone_frame_2_0037.png
# leone_frame_2_0038.png
# leone_frame_2_0039.png
# leone_frame_2_0040.png
# leone_frame_2_0041.png
# leone_frame_2_0042.png
# leone_frame_2_0043.png
# leone_frame_2_0044.png
# leone_frame_2_0045.png
# leone_frame_2_0046.png
# leone_frame_2_0047.png
# leone_frame_2_0048.png
# leone_frame_3_0001.png
# leone_frame_3_0002.png
# leone_frame_3_0003.png
# leone_frame_3_0004.png
# leone_frame_3_0005.png
# leone_frame_3_0006.png
# leone_frame_3_0007.png
# leone_frame_3_0008.png
# leone_frame_3_0009.png
# leone_frame_3_0010.png
# leone_frame_3_0011.png
# leone_frame_3_0012.png
# leone_frame_3_0013.png
# leone_frame_3_0014.png
# leone_frame_3_0015.png
# leone_frame_3_0016.png
# leone_frame_3_0017.png
# leone_frame_3_0018.png
# leone_frame_3_0019.png
# leone_frame_3_0020.png
# leone_frame_3_0021.png
# leone_frame_3_0022.png
# leone_frame_3_0023.png
# leone_frame_3_0024.png
# leone_frame_3_0025.png
# leone_frame_3_0026.png
# leone_frame_3_0027.png
# leone_frame_3_0028.png
# leone_frame_3_0029.png
# leone_frame_3_0030.png
# leone_frame_3_0031.png
# leone_frame_3_0032.png
# leone_frame_3_0033.png
# leone_frame_3_0034.png
# leone_frame_3_0035.png
# leone_frame_3_0036.png
# leone_frame_3_0037.png
# leone_frame_3_0038.png
# leone_frame_3_0039.png
# leone_frame_3_0040.png
# leone_frame_3_0041.png
# leone_frame_3_0042.png
# leone_frame_3_0043.png
# leone_frame_3_0044.png
# leone_frame_3_0045.png
# leone_frame_3_0046.png
# leone_frame_3_0047.png
# leone_frame_3_0048.png
# leone_frame_4_0001.png
# leone_frame_4_0002.png
# leone_frame_4_0003.png
# leone_frame_4_0004.png
# leone_frame_4_0005.png
# leone_frame_4_0006.png
# leone_frame_4_0007.png
# leone_frame_4_0008.png
# leone_frame_4_0009.png
# leone_frame_4_0010.png
# leone_frame_4_0011.png
# leone_frame_4_0012.png
# leone_frame_4_0013.png
# leone_frame_4_0014.png
# leone_frame_4_0015.png
# leone_frame_4_0016.png
# leone_frame_4_0017.png
# leone_frame_4_0018.png
# leone_frame_4_0019.png
# leone_frame_4_0020.png
# leone_frame_4_0021.png
# leone_frame_4_0022.png
# leone_frame_4_0023.png
# leone_frame_4_0024.png
# leone_frame_4_0025.png
# leone_frame_4_0026.png
# leone_frame_4_0027.png
# leone_frame_4_0028.png
# leone_frame_4_0029.png
# leone_frame_4_0030.png
# leone_frame_4_0031.png
# leone_frame_4_0032.png
# leone_frame_4_0033.png
# leone_frame_4_0034.png
# leone_frame_4_0035.png
# leone_frame_4_0036.png
# leone_frame_4_0037.png
# leone_frame_4_0038.png
# leone_frame_4_0039.png
# leone_frame_4_0040.png
# leone_frame_4_0041.png
# leone_frame_4_0042.png
# leone_frame_4_0043.png
# leone_frame_4_0044.png
# leone_frame_4_0045.png
# leone_frame_4_0046.png
# leone_frame_4_0047.png
# leone_frame_4_0048.png

# %% [markdown]
# ### **Execution**

# %%
factor = 20
df_per_patch_counts_rescaled = df_per_patch_counts.copy()
df_per_patch_counts_rescaled['Counts'] = df_per_patch_counts_rescaled['Counts'] * factor
# df_per_patch_counts_rescaled[df_per_patch_counts_rescaled['Type']!='dirt', 'Counts'] = df_per_patch_counts_rescaled[df_per_patch_counts_rescaled['Type']!='dirt', 'Counts'] * factor
# df_per_patch_counts_rescaled[df_per_patch_counts_rescaled['Type']=='dirt', 'Counts'] = df_per_patch_counts_rescaled[df_per_patch_counts_rescaled['Type']=='dirt', 'Counts'] * factor//2

# %%
df_per_patch_counts_rescaled[df_per_patch_counts_rescaled['Type']=='long hair', 'Counts'] = df_per_patch_counts_rescaled['Counts']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df_per_patch_counts_rescaled[df_per_patch_counts_rescaled['Type']=='long hair', 'Counts'] = df_per_patch_counts_rescaled['Counts']
#
# File ~/miniconda3/lib/python3.13/site-packages/pandas/core/frame.py:4311, in DataFrame.__setitem__(self, key, value)
#    4308     self._setitem_array([key], value)
#    4309 else:
#    4310     # set column
# -> 4311     self._set_item(key, value)
#
# File ~/miniconda3/lib/python3.13/site-packages/pandas/core/frame.py:4527, in DataFrame._set_item(self, key, value)
#    4515 """
#    4516 Add series to DataFrame in specified column.
#    4517
#    (...)   4522 ensure homogeneity.
#    4523 """
#    4524 value, refs = self._sanitize_column(value)
#    4526 if (
# -> 4527     key in self.columns
#    4528     and value.ndim == 1
#    4529     and not isinstance(value.dtype, ExtensionDtype)
#    4530 ):
#    4531     # broadcast across multiple columns if necessary
#    4532     if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#    4533         existing_piece = self[key]
#
# File ~/miniconda3/lib/python3.13/site-packages/pandas/core/indexes/base.py:5358, in Index.__contains__(self, key)
#    5323 def __contains__(self, key: Any) -> bool:
#    5324     """
#    5325     Return a boolean indicating whether the provided key is in the index.
#    5326
#    (...)   5356     False
#    5357     """
# -> 5358     hash(key)
#    5359     try:
#    5360         return key in self._engine
#
# TypeError: unhashable type: 'Series'

# %%
# multiply the counts of scratches by 2 (Types == scratches)
df_per_patch_counts_rescaled_more_hair.loc[df_per_patch_counts_rescaled_more_hair['Type'] == 'long hair', 'Counts'] *= 3

# %%
def generate_n_masks(height, width, n, output_folder):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    for i in range(n):
        print(f"Generating mask {i}")

        mask, binary_mask, perlin_noise = create_random_mask_with_transparency((height, width), df_artifacts, df_synthetic, df_per_patch_counts_rescaled, use_synthetic=synthetic, rescale=rescale, uniform_sample=uniform, verbose=verbose, alpha_prob = 0.7)
        if not os.path.exists(output_folder):
            os.makedirs(output_folder)
        print(f"Saving mask {i}")
        cv.imwrite(output_folder+"mask_"+str(i)+".png", mask)

# %%
img = cv.imread("./figures/bueno_feo_malo_frame_0001.png")
height, width = img.shape[:2]

# %%
print(height, width)
# Out:
# 816 1920

# %%
mask = generate_n_masks(1600, 1920, 20000, "./biggest_big_masks/")
import requests
requests.post("https://ntfy.sh/tfg-pol", data = "Finished generating masks",
            headers={"title": "Mask generation",})
# Out:
# Generating mask 0
# Saving mask 0
# Generating mask 1
# Saving mask 1
# Generating mask 2
# Saving mask 2
# Generating mask 3
# Saving mask 3
# Generating mask 4
# Saving mask 4
# Generating mask 5
# Saving mask 5
# Generating mask 6
# Saving mask 6
# Generating mask 7
# Saving mask 7
# Generating mask 8
# Saving mask 8
# Generating mask 9
# Saving mask 9
# Generating mask 10
# Saving mask 10
# Generating mask 11
# Saving mask 11
# Generating mask 12
# Saving mask 12
# Generating mask 13
# Saving mask 13
# Generating mask 14
# Saving mask 14
# Generating mask 15
# Saving mask 15
# Generating mask 16
# Saving mask 16
# Generating mask 17
# Saving mask 17
# Generating mask 18
# Saving mask 18
# Generating mask 19
# Saving mask 19
# Generating mask 20
# Saving mask 20
# Generating mask 21
# Saving mask 21
# Generating mask 22
# Saving mask 22
# Generating mask 23
# Saving mask 23
# Generating mask 24
# Saving mask 24
# Generating mask 25
# Saving mask 25
# Generating mask 26
# Saving mask 26
# Generating mask 27
# Saving mask 27
# Generating mask 28
# Saving mask 28
# Generating mask 29
# Saving mask 29
# Generating mask 30
# Saving mask 30
# Generating mask 31
# Saving mask 31
# Generating mask 32
# Saving mask 32
# Generating mask 33
# Saving mask 33
# Generating mask 34
# Saving mask 34
# Generating mask 35
# Saving mask 35
# Generating mask 36
# Saving mask 36
# Generating mask 37
# Saving mask 37
# Generating mask 38
# Saving mask 38
# Generating mask 39
# Saving mask 39
# Generating mask 40
# Saving mask 40
# Generating mask 41
# Saving mask 41
# Generating mask 42
# Saving mask 42
# Generating mask 43
# Saving mask 43
# Generating mask 44
# Saving mask 44
# Generating mask 45
# Saving mask 45
# Generating mask 46
# Saving mask 46
# Generating mask 47
# Saving mask 47
# Generating mask 48
# Saving mask 48
# Generating mask 49
# Saving mask 49
# Generating mask 50
# Saving mask 50
# Generating mask 51
# Saving mask 51
# Generating mask 52
# Saving mask 52
# Generating mask 53
# Saving mask 53
# Generating mask 54
# Saving mask 54
# Generating mask 55
# Saving mask 55
# Generating mask 56
# Saving mask 56
# Generating mask 57
# Saving mask 57
# Generating mask 58
# Saving mask 58
# Generating mask 59
# Saving mask 59
# Generating mask 60
# libpng error: Write Error
# Saving mask 60
# Generating mask 61
# libpng error: Write Error
# Saving mask 61
# Generating mask 62
# Saving mask 62
# Generating mask 63
# Saving mask 63
# Generating mask 64
# Saving mask 64
# Generating mask 65
# Saving mask 65
# Generating mask 66
# Saving mask 66
# Generating mask 67
# Saving mask 67
# Generating mask 68
# Saving mask 68
# Generating mask 69
# Saving mask 69
# Generating mask 70
# Saving mask 70
# Generating mask 71
# Saving mask 71
# Generating mask 72
# Saving mask 72
# Generating mask 73
# Saving mask 73
# Generating mask 74
# Saving mask 74
# Generating mask 75
# Saving mask 75
# Generating mask 76
# Saving mask 76
# Generating mask 77
# Saving mask 77
# Generating mask 78
# Saving mask 78
# Generating mask 79
# Saving mask 79
# Generating mask 80
# Saving mask 80
# Generating mask 81
# Saving mask 81
# Generating mask 82
# Saving mask 82
# Generating mask 83
# Saving mask 83
# Generating mask 84
# Saving mask 84
# Generating mask 85
# Saving mask 85
# Generating mask 86
# Saving mask 86
# Generating mask 87
# Saving mask 87
# Generating mask 88
# Saving mask 88
# Generating mask 89
# Saving mask 89
# Generating mask 90
# Saving mask 90
# Generating mask 91
# Saving mask 91
# Generating mask 92
# Saving mask 92
# Generating mask 93
# Saving mask 93
# Generating mask 94
# Saving mask 94
# Generating mask 95
# Saving mask 95
# Generating mask 96
# Saving mask 96
# Generating mask 97
# Saving mask 97
# Generating mask 98
# Saving mask 98
# Generating mask 99
# Saving mask 99
# Generating mask 100
# Saving mask 100
# Generating mask 101
# Saving mask 101
# Generating mask 102
# Saving mask 102
# Generating mask 103
# Saving mask 103
# Generating mask 104
# Saving mask 104
# Generating mask 105
# Saving mask 105
# Generating mask 106
# Saving mask 106
# Generating mask 107
# Saving mask 107
# Generating mask 108
# Saving mask 108
# Generating mask 109
# Saving mask 109
# Generating mask 110
# Saving mask 110
# Generating mask 111
# Saving mask 111
# Generating mask 112
# Saving mask 112
# Generating mask 113
# Saving mask 113
# Generating mask 114
# Saving mask 114
# Generating mask 115
# Saving mask 115
# Generating mask 116
# Saving mask 116
# Generating mask 117
# Saving mask 117
# Generating mask 118
# Saving mask 118
# Generating mask 119
# Saving mask 119
# Generating mask 120
# Saving mask 120
# Generating mask 121
# Saving mask 121
# Generating mask 122
# Saving mask 122
# Generating mask 123
# Saving mask 123
# Generating mask 124
# Saving mask 124
# Generating mask 125
# Saving mask 125
# Generating mask 126
# Saving mask 126
# Generating mask 127
# Saving mask 127
# Generating mask 128
# Saving mask 128
# Generating mask 129
# Saving mask 129
# Generating mask 130
# Saving mask 130
# Generating mask 131
# Saving mask 131
# Generating mask 132
# Saving mask 132
# Generating mask 133
# Saving mask 133
# Generating mask 134
# Saving mask 134
# Generating mask 135
# Saving mask 135
# Generating mask 136
# Saving mask 136
# Generating mask 137
# Saving mask 137
# Generating mask 138
# Saving mask 138
# Generating mask 139
# Saving mask 139
# Generating mask 140
# Saving mask 140
# Generating mask 141
# Saving mask 141
# Generating mask 142
# Saving mask 142
# Generating mask 143
# Saving mask 143
# Generating mask 144
# Saving mask 144
# Generating mask 145
# Saving mask 145
# Generating mask 146
# Saving mask 146
# Generating mask 147
# Saving mask 147
# Generating mask 148
# Saving mask 148
# Generating mask 149
# Saving mask 149
# Generating mask 150
# Saving mask 150
# Generating mask 151
# Saving mask 151
# Generating mask 152
# Saving mask 152
# Generating mask 153
# Saving mask 153
# Generating mask 154
# Saving mask 154
# Generating mask 155
# Saving mask 155
# Generating mask 156
# Saving mask 156
# Generating mask 157
# Saving mask 157
# Generating mask 158
# Saving mask 158
# Generating mask 159
# Saving mask 159
# Generating mask 160
# Saving mask 160
# Generating mask 161
# Saving mask 161
# Generating mask 162
# Saving mask 162
# Generating mask 163
# Saving mask 163
# Generating mask 164
# Saving mask 164
# Generating mask 165
# Saving mask 165
# Generating mask 166
# Saving mask 166
# Generating mask 167
# Saving mask 167
# Generating mask 168
# Saving mask 168
# Generating mask 169
# Saving mask 169
# Generating mask 170
# Saving mask 170
# Generating mask 171
# Saving mask 171
# Generating mask 172
# Saving mask 172
# Generating mask 173
# Saving mask 173
# Generating mask 174
# Saving mask 174
# Generating mask 175
# Saving mask 175
# Generating mask 176
# Saving mask 176
# Generating mask 177
# Saving mask 177
# Generating mask 178
# Saving mask 178
# Generating mask 179
# Saving mask 179
# Generating mask 180
# Saving mask 180
# Generating mask 181
# Saving mask 181
# Generating mask 182
# Saving mask 182
# Generating mask 183
# Saving mask 183
# Generating mask 184
# Saving mask 184
# Generating mask 185
# Saving mask 185
# Generating mask 186
# Saving mask 186
# Generating mask 187
# Saving mask 187
# Generating mask 188
# Saving mask 188
# Generating mask 189
# Saving mask 189
# Generating mask 190
# Saving mask 190
# Generating mask 191
# Saving mask 191
# Generating mask 192
# Saving mask 192
# Generating mask 193
# Saving mask 193
# Generating mask 194
# Saving mask 194
# Generating mask 195
# Saving mask 195
# Generating mask 196
# Saving mask 196
# Generating mask 197
# Saving mask 197
# Generating mask 198
# Saving mask 198
# Generating mask 199
# Saving mask 199
# Generating mask 200
# Saving mask 200
# Generating mask 201
# Saving mask 201
# Generating mask 202
# Saving mask 202
# Generating mask 203
# Saving mask 203
# Generating mask 204
# Saving mask 204
# Generating mask 205
# Saving mask 205
# Generating mask 206
# Saving mask 206
# Generating mask 207
# Saving mask 207
# Generating mask 208
# Saving mask 208
# Generating mask 209
# Saving mask 209
# Generating mask 210
# Saving mask 210
# Generating mask 211
# Saving mask 211
# Generating mask 212
# Saving mask 212
# Generating mask 213
# Saving mask 213
# Generating mask 214
# Saving mask 214
# Generating mask 215
# Saving mask 215
# Generating mask 216
# Saving mask 216
# Generating mask 217
# Saving mask 217
# Generating mask 218
# Saving mask 218
# Generating mask 219
# Saving mask 219
# Generating mask 220
# Saving mask 220
# Generating mask 221
# Saving mask 221
# Generating mask 222
# Saving mask 222
# Generating mask 223
# Saving mask 223
# Generating mask 224
# Saving mask 224
# Generating mask 225
# Saving mask 225
# Generating mask 226
# Saving mask 226
# Generating mask 227
# Saving mask 227
# Generating mask 228
# Saving mask 228
# Generating mask 229
# Saving mask 229
# Generating mask 230
# Saving mask 230
# Generating mask 231
# Saving mask 231
# Generating mask 232
# Saving mask 232
# Generating mask 233
# Saving mask 233
# Generating mask 234
# Saving mask 234
# Generating mask 235
# Saving mask 235
# Generating mask 236
# Saving mask 236
# Generating mask 237
# Saving mask 237
# Generating mask 238
# Saving mask 238
# Generating mask 239
# Saving mask 239
# Generating mask 240
# Saving mask 240
# Generating mask 241
# Saving mask 241
# Generating mask 242
# Saving mask 242
# Generating mask 243
# Saving mask 243
# Generating mask 244
# Saving mask 244
# Generating mask 245
# Saving mask 245
# Generating mask 246
# Saving mask 246
# Generating mask 247
# Saving mask 247
# Generating mask 248
# Saving mask 248
# Generating mask 249
# Saving mask 249
# Generating mask 250
# Saving mask 250
# Generating mask 251
# Saving mask 251
# Generating mask 252
# Saving mask 252
# Generating mask 253
# Saving mask 253
# Generating mask 254
# Saving mask 254
# Generating mask 255
# Saving mask 255
# Generating mask 256
# Saving mask 256
# Generating mask 257
# Saving mask 257
# Generating mask 258
# Saving mask 258
# Generating mask 259
# Saving mask 259
# Generating mask 260
# Saving mask 260
# Generating mask 261
# Saving mask 261
# Generating mask 262
# Saving mask 262
# Generating mask 263
# Saving mask 263
# Generating mask 264
# Saving mask 264
# Generating mask 265
# Saving mask 265
# Generating mask 266
# Saving mask 266
# Generating mask 267
# Saving mask 267
# Generating mask 268
# Saving mask 268
# Generating mask 269
# Saving mask 269
# Generating mask 270
# Saving mask 270
# Generating mask 271
# Saving mask 271
# Generating mask 272
# Saving mask 272
# Generating mask 273
# Saving mask 273
# Generating mask 274
# Saving mask 274
# Generating mask 275
# Saving mask 275
# Generating mask 276
# Saving mask 276
# Generating mask 277
# Saving mask 277
# Generating mask 278
# Saving mask 278
# Generating mask 279
# Saving mask 279
# Generating mask 280
# Saving mask 280
# Generating mask 281
# Saving mask 281
# Generating mask 282
# Saving mask 282
# Generating mask 283
# Saving mask 283
# Generating mask 284
# Saving mask 284
# Generating mask 285
# Saving mask 285
# Generating mask 286
# Saving mask 286
# Generating mask 287
# Saving mask 287
# Generating mask 288
# Saving mask 288
# Generating mask 289
# Saving mask 289
# Generating mask 290
# Saving mask 290
# Generating mask 291
# Saving mask 291
# Generating mask 292
# Saving mask 292
# Generating mask 293
# Saving mask 293
# Generating mask 294
# Saving mask 294
# Generating mask 295
# Saving mask 295
# Generating mask 296
# Saving mask 296
# Generating mask 297
# Saving mask 297
# Generating mask 298
# Saving mask 298
# Generating mask 299
# Saving mask 299
# Generating mask 300
# Saving mask 300
# Generating mask 301
# Saving mask 301
# Generating mask 302
# Saving mask 302
# Generating mask 303
# Saving mask 303
# Generating mask 304
# Saving mask 304
# Generating mask 305
# Saving mask 305
# Generating mask 306
# Saving mask 306
# Generating mask 307
# Saving mask 307
# Generating mask 308
# Saving mask 308
# Generating mask 309
# Saving mask 309
# Generating mask 310
# Saving mask 310
# Generating mask 311
# Saving mask 311
# Generating mask 312
# Saving mask 312
# Generating mask 313
# Saving mask 313
# Generating mask 314
# Saving mask 314
# Generating mask 315
# Saving mask 315
# Generating mask 316
# Saving mask 316
# Generating mask 317
# Saving mask 317
# Generating mask 318
# Saving mask 318
# Generating mask 319
# Saving mask 319
# Generating mask 320
# Saving mask 320
# Generating mask 321
# Saving mask 321
# Generating mask 322
# Saving mask 322
# Generating mask 323
# Saving mask 323
# Generating mask 324
# Saving mask 324
# Generating mask 325
# Saving mask 325
# Generating mask 326
# Saving mask 326
# Generating mask 327
# Saving mask 327
# Generating mask 328
# Saving mask 328
# Generating mask 329
# Saving mask 329
# Generating mask 330
# Saving mask 330
# Generating mask 331
# Saving mask 331
# Generating mask 332
# Saving mask 332
# Generating mask 333
# Saving mask 333
# Generating mask 334
# Saving mask 334
# Generating mask 335
# Saving mask 335
# Generating mask 336
# Saving mask 336
# Generating mask 337
# Saving mask 337
# Generating mask 338
# Saving mask 338
# Generating mask 339
# Saving mask 339
# Generating mask 340
# Saving mask 340
# Generating mask 341
# Saving mask 341
# Generating mask 342
# Saving mask 342
# Generating mask 343
# Saving mask 343
# Generating mask 344
# Saving mask 344
# Generating mask 345
# Saving mask 345
# Generating mask 346
# Saving mask 346
# Generating mask 347
# Saving mask 347
# Generating mask 348
# Saving mask 348
# Generating mask 349
# Saving mask 349
# Generating mask 350
# Saving mask 350
# Generating mask 351
# Saving mask 351
# Generating mask 352
# Saving mask 352
# Generating mask 353
# Saving mask 353
# Generating mask 354
# Saving mask 354
# Generating mask 355
# Saving mask 355
# Generating mask 356
# Saving mask 356
# Generating mask 357
# Saving mask 357
# Generating mask 358
# Saving mask 358
# Generating mask 359
# Saving mask 359
# Generating mask 360
# Saving mask 360
# Generating mask 361
# Saving mask 361
# Generating mask 362
# Saving mask 362
# Generating mask 363
# Saving mask 363
# Generating mask 364
# Saving mask 364
# Generating mask 365
# Saving mask 365
# Generating mask 366
# Saving mask 366
# Generating mask 367
# Saving mask 367
# Generating mask 368
# Saving mask 368
# Generating mask 369
# Saving mask 369
# Generating mask 370
# Saving mask 370
# Generating mask 371
# Saving mask 371
# Generating mask 372
# Saving mask 372
# Generating mask 373
# Saving mask 373
# Generating mask 374
# Saving mask 374
# Generating mask 375
# Saving mask 375
# Generating mask 376
# Saving mask 376
# Generating mask 377
# Saving mask 377
# Generating mask 378
# Saving mask 378
# Generating mask 379
# Saving mask 379
# Generating mask 380
# Saving mask 380
# Generating mask 381
# Saving mask 381
# Generating mask 382
# Saving mask 382
# Generating mask 383
# Saving mask 383
# Generating mask 384
# Saving mask 384
# Generating mask 385
# Saving mask 385
# Generating mask 386
# Saving mask 386
# Generating mask 387
# Saving mask 387
# Generating mask 388
# Saving mask 388
# Generating mask 389
# Saving mask 389
# Generating mask 390
# Saving mask 390
# Generating mask 391
# Saving mask 391
# Generating mask 392
# Saving mask 392
# Generating mask 393
# Saving mask 393
# Generating mask 394
# Saving mask 394
# Generating mask 395
# Saving mask 395
# Generating mask 396
# Saving mask 396
# Generating mask 397
# Saving mask 397
# Generating mask 398
# Saving mask 398
# Generating mask 399
# Saving mask 399
# Generating mask 400
# Saving mask 400
# Generating mask 401
# Saving mask 401
# Generating mask 402
# Saving mask 402
# Generating mask 403
# Saving mask 403
# Generating mask 404
# Saving mask 404
# Generating mask 405
# Saving mask 405
# Generating mask 406
# Saving mask 406
# Generating mask 407
# Saving mask 407
# Generating mask 408
# Saving mask 408
# Generating mask 409
# Saving mask 409
# Generating mask 410
# Saving mask 410
# Generating mask 411
# Saving mask 411
# Generating mask 412
# Saving mask 412
# Generating mask 413
# Saving mask 413
# Generating mask 414
# Saving mask 414
# Generating mask 415
# Saving mask 415
# Generating mask 416
# Saving mask 416
# Generating mask 417
# Saving mask 417
# Generating mask 418
# Saving mask 418
# Generating mask 419
# Saving mask 419
# Generating mask 420
# Saving mask 420
# Generating mask 421
# Saving mask 421
# Generating mask 422
# Saving mask 422
# Generating mask 423
# Saving mask 423
# Generating mask 424
# Saving mask 424
# Generating mask 425
# Saving mask 425
# Generating mask 426
# Saving mask 426
# Generating mask 427
# Saving mask 427
# Generating mask 428
# Saving mask 428
# Generating mask 429
# Saving mask 429
# Generating mask 430
# Saving mask 430
# Generating mask 431
# Saving mask 431
# Generating mask 432
# Saving mask 432
# Generating mask 433
# Saving mask 433
# Generating mask 434
# Saving mask 434
# Generating mask 435
# Saving mask 435
# Generating mask 436
# Saving mask 436
# Generating mask 437
# Saving mask 437
# Generating mask 438
# Saving mask 438
# Generating mask 439
# Saving mask 439
# Generating mask 440
# Saving mask 440
# Generating mask 441
# Saving mask 441
# Generating mask 442
# Saving mask 442
# Generating mask 443
# Saving mask 443
# Generating mask 444
# Saving mask 444
# Generating mask 445
# Saving mask 445
# Generating mask 446
# Saving mask 446
# Generating mask 447
# Saving mask 447
# Generating mask 448
# Saving mask 448
# Generating mask 449
# Saving mask 449
# Generating mask 450
# Saving mask 450
# Generating mask 451
# Saving mask 451
# Generating mask 452
# Saving mask 452
# Generating mask 453
# Saving mask 453
# Generating mask 454
# Saving mask 454
# Generating mask 455
# Saving mask 455
# Generating mask 456
# Saving mask 456
# Generating mask 457
# Saving mask 457
# Generating mask 458
# Saving mask 458
# Generating mask 459
# Saving mask 459
# Generating mask 460
# Saving mask 460
# Generating mask 461
# Saving mask 461
# Generating mask 462
# Saving mask 462
# Generating mask 463
# Saving mask 463
# Generating mask 464
# Saving mask 464
# Generating mask 465
# Saving mask 465
# Generating mask 466
# Saving mask 466
# Generating mask 467
# Saving mask 467
# Generating mask 468
# Saving mask 468
# Generating mask 469
# Saving mask 469
# Generating mask 470
# Saving mask 470
# Generating mask 471
# Saving mask 471
# Generating mask 472
# Saving mask 472
# Generating mask 473
# Saving mask 473
# Generating mask 474
# Saving mask 474
# Generating mask 475
# Saving mask 475
# Generating mask 476
# Saving mask 476
# Generating mask 477
# Saving mask 477
# Generating mask 478
# Saving mask 478
# Generating mask 479
# Saving mask 479
# Generating mask 480
# Saving mask 480
# Generating mask 481
# Saving mask 481
# Generating mask 482
# Saving mask 482
# Generating mask 483
# Saving mask 483
# Generating mask 484
# Saving mask 484
# Generating mask 485
# Saving mask 485
# Generating mask 486
# Saving mask 486
# Generating mask 487
# Saving mask 487
# Generating mask 488
# Saving mask 488
# Generating mask 489
# Saving mask 489
# Generating mask 490
# Saving mask 490
# Generating mask 491
# Saving mask 491
# Generating mask 492
# Saving mask 492
# Generating mask 493
# Saving mask 493
# Generating mask 494
# Saving mask 494
# Generating mask 495
# Saving mask 495
# Generating mask 496
# Saving mask 496
# Generating mask 497
# Saving mask 497
# Generating mask 498
# Saving mask 498
# Generating mask 499
# Saving mask 499
# Generating mask 500
# Saving mask 500
# Generating mask 501
# Saving mask 501
# Generating mask 502
# Saving mask 502
# Generating mask 503
# Saving mask 503
# Generating mask 504
# Saving mask 504
# Generating mask 505
# Saving mask 505
# Generating mask 506
# Saving mask 506
# Generating mask 507
# Saving mask 507
# Generating mask 508
# Saving mask 508
# Generating mask 509
# Saving mask 509
# Generating mask 510
# Saving mask 510
# Generating mask 511
# Saving mask 511
# Generating mask 512
# Saving mask 512
# Generating mask 513
# Saving mask 513
# Generating mask 514
# Saving mask 514
# Generating mask 515
# Saving mask 515
# Generating mask 516
# Saving mask 516
# Generating mask 517
# Saving mask 517
# Generating mask 518
# Saving mask 518
# Generating mask 519
# Saving mask 519
# Generating mask 520
# Saving mask 520
# Generating mask 521
# Saving mask 521
# Generating mask 522
# Saving mask 522
# Generating mask 523
# Saving mask 523
# Generating mask 524
# Saving mask 524
# Generating mask 525
# Saving mask 525
# Generating mask 526
# Saving mask 526
# Generating mask 527
# Saving mask 527
# Generating mask 528
# Saving mask 528
# Generating mask 529
# Saving mask 529
# Generating mask 530
# Saving mask 530
# Generating mask 531
# Saving mask 531
# Generating mask 532
# Saving mask 532
# Generating mask 533
# Saving mask 533
# Generating mask 534
# Saving mask 534
# Generating mask 535
# Saving mask 535
# Generating mask 536
# Saving mask 536
# Generating mask 537
# Saving mask 537
# Generating mask 538
# Saving mask 538
# Generating mask 539
# Saving mask 539
# Generating mask 540
# Saving mask 540
# Generating mask 541
# Saving mask 541
# Generating mask 542
# Saving mask 542
# Generating mask 543
# Saving mask 543
# Generating mask 544
# Saving mask 544
# Generating mask 545
# Saving mask 545
# Generating mask 546
# Saving mask 546
# Generating mask 547
# Saving mask 547
# Generating mask 548
# Saving mask 548
# Generating mask 549
# Saving mask 549
# Generating mask 550
# Saving mask 550
# Generating mask 551
# Saving mask 551
# Generating mask 552
# Saving mask 552
# Generating mask 553
# Saving mask 553
# Generating mask 554
# Saving mask 554
# Generating mask 555
# Saving mask 555
# Generating mask 556
# Saving mask 556
# Generating mask 557
# Saving mask 557
# Generating mask 558
# Saving mask 558
# Generating mask 559
# Saving mask 559
# Generating mask 560
# Saving mask 560
# Generating mask 561
# Saving mask 561
# Generating mask 562
# Saving mask 562
# Generating mask 563
# Saving mask 563
# Generating mask 564
# Saving mask 564
# Generating mask 565
# Saving mask 565
# Generating mask 566
# Saving mask 566
# Generating mask 567
# Saving mask 567
# Generating mask 568
# Saving mask 568
# Generating mask 569
# Saving mask 569
# Generating mask 570
# Saving mask 570
# Generating mask 571
# Saving mask 571
# Generating mask 572
# Saving mask 572
# Generating mask 573
# Saving mask 573
# Generating mask 574
# Saving mask 574
# Generating mask 575
# Saving mask 575
# Generating mask 576
# Saving mask 576
# Generating mask 577
# Saving mask 577
# Generating mask 578
# Saving mask 578
# Generating mask 579
# Saving mask 579
# Generating mask 580
# Saving mask 580
# Generating mask 581
# Saving mask 581
# Generating mask 582
# Saving mask 582
# Generating mask 583
# Saving mask 583
# Generating mask 584
# Saving mask 584
# Generating mask 585
# Saving mask 585
# Generating mask 586
# Saving mask 586
# Generating mask 587
# Saving mask 587
# Generating mask 588
# Saving mask 588
# Generating mask 589
# Saving mask 589
# Generating mask 590
# Saving mask 590
# Generating mask 591
# Saving mask 591
# Generating mask 592
# Saving mask 592
# Generating mask 593
# Saving mask 593
# Generating mask 594
# Saving mask 594
# Generating mask 595
# Saving mask 595
# Generating mask 596
# Saving mask 596
# Generating mask 597
# Saving mask 597
# Generating mask 598
# Saving mask 598
# Generating mask 599
# Saving mask 599
# Generating mask 600
# Saving mask 600
# Generating mask 601
# Saving mask 601
# Generating mask 602
# Saving mask 602
# Generating mask 603
# Saving mask 603
# Generating mask 604
# Saving mask 604
# Generating mask 605
# Saving mask 605
# Generating mask 606
# Saving mask 606
# Generating mask 607
# Saving mask 607
# Generating mask 608
# Saving mask 608
# Generating mask 609
# Saving mask 609
# Generating mask 610
# Saving mask 610
# Generating mask 611
# Saving mask 611
# Generating mask 612
# Saving mask 612
# Generating mask 613
# Saving mask 613
# Generating mask 614
# Saving mask 614
# Generating mask 615
# Saving mask 615
# Generating mask 616
# Saving mask 616
# Generating mask 617
# Saving mask 617
# Generating mask 618
# Saving mask 618
# Generating mask 619
# Saving mask 619
# Generating mask 620
# Saving mask 620
# Generating mask 621
# Saving mask 621
# Generating mask 622
# Saving mask 622
# Generating mask 623
# Saving mask 623
# Generating mask 624
# Saving mask 624
# Generating mask 625
# Saving mask 625
# Generating mask 626
# Saving mask 626
# Generating mask 627
# Saving mask 627
# Generating mask 628
# Saving mask 628
# Generating mask 629
# Saving mask 629
# Generating mask 630
# Saving mask 630
# Generating mask 631
# Saving mask 631
# Generating mask 632
# Saving mask 632
# Generating mask 633
# Saving mask 633
# Generating mask 634
# Saving mask 634
# Generating mask 635
# Saving mask 635
# Generating mask 636
# Saving mask 636
# Generating mask 637
# Saving mask 637
# Generating mask 638
# Saving mask 638
# Generating mask 639
# Saving mask 639
# Generating mask 640
# Saving mask 640
# Generating mask 641
# Saving mask 641
# Generating mask 642
# Saving mask 642
# Generating mask 643
# Saving mask 643
# Generating mask 644
# Saving mask 644
# Generating mask 645
# Saving mask 645
# Generating mask 646
# Saving mask 646
# Generating mask 647
# Saving mask 647
# Generating mask 648
# Saving mask 648
# Generating mask 649
# Saving mask 649
# Generating mask 650
# Saving mask 650
# Generating mask 651
# Saving mask 651
# Generating mask 652
# Saving mask 652
# Generating mask 653
# Saving mask 653
# Generating mask 654
# Saving mask 654
# Generating mask 655
# Saving mask 655
# Generating mask 656
# Saving mask 656
# Generating mask 657
# Saving mask 657
# Generating mask 658
# Saving mask 658
# Generating mask 659
# Saving mask 659
# Generating mask 660
# Saving mask 660
# Generating mask 661
# Saving mask 661
# Generating mask 662
# Saving mask 662
# Generating mask 663
# Saving mask 663
# Generating mask 664
# Saving mask 664
# Generating mask 665
# Saving mask 665
# Generating mask 666
# Saving mask 666
# Generating mask 667
# Saving mask 667
# Generating mask 668
# Saving mask 668
# Generating mask 669
# Saving mask 669
# Generating mask 670
# Saving mask 670
# Generating mask 671
# Saving mask 671
# Generating mask 672
# Saving mask 672
# Generating mask 673
# Saving mask 673
# Generating mask 674
# Saving mask 674
# Generating mask 675
# Saving mask 675
# Generating mask 676
# Saving mask 676
# Generating mask 677
# Saving mask 677
# Generating mask 678
# Saving mask 678
# Generating mask 679
# Saving mask 679
# Generating mask 680
# Saving mask 680
# Generating mask 681
# Saving mask 681
# Generating mask 682
# Saving mask 682
# Generating mask 683
# Saving mask 683
# Generating mask 684
# Saving mask 684
# Generating mask 685
# Saving mask 685
# Generating mask 686
# Saving mask 686
# Generating mask 687
# Saving mask 687
# Generating mask 688
# Saving mask 688
# Generating mask 689
# Saving mask 689
# Generating mask 690
# Saving mask 690
# Generating mask 691
# Saving mask 691
# Generating mask 692
# Saving mask 692
# Generating mask 693
# Saving mask 693
# Generating mask 694
# Saving mask 694
# Generating mask 695
# Saving mask 695
# Generating mask 696
# Saving mask 696
# Generating mask 697
# Saving mask 697
# Generating mask 698
# Saving mask 698
# Generating mask 699
# Saving mask 699
# Generating mask 700
# Saving mask 700
# Generating mask 701
# Saving mask 701
# Generating mask 702
# Saving mask 702
# Generating mask 703
# Saving mask 703
# Generating mask 704
# Saving mask 704
# Generating mask 705
# Saving mask 705
# Generating mask 706
# Saving mask 706
# Generating mask 707
# Saving mask 707
# Generating mask 708
# Saving mask 708
# Generating mask 709
# Saving mask 709
# Generating mask 710
# Saving mask 710
# Generating mask 711
# Saving mask 711
# Generating mask 712
# Saving mask 712
# Generating mask 713
# Saving mask 713
# Generating mask 714
# Saving mask 714
# Generating mask 715
# Saving mask 715
# Generating mask 716
# Saving mask 716
# Generating mask 717
# Saving mask 717
# Generating mask 718
# Saving mask 718
# Generating mask 719
# Saving mask 719
# Generating mask 720
# Saving mask 720
# Generating mask 721
# Saving mask 721
# Generating mask 722
# Saving mask 722
# Generating mask 723
# Saving mask 723
# Generating mask 724
# Saving mask 724
# Generating mask 725
# Saving mask 725
# Generating mask 726
# Saving mask 726
# Generating mask 727
# Saving mask 727
# Generating mask 728
# Saving mask 728
# Generating mask 729
# Saving mask 729
# Generating mask 730
# Saving mask 730
# Generating mask 731
# Saving mask 731
# Generating mask 732
# Saving mask 732
# Generating mask 733
# Saving mask 733
# Generating mask 734
# Saving mask 734
# Generating mask 735
# Saving mask 735
# Generating mask 736
# Saving mask 736
# Generating mask 737
# Saving mask 737
# Generating mask 738
# Saving mask 738
# Generating mask 739
# Saving mask 739
# Generating mask 740
# Saving mask 740
# Generating mask 741
# Saving mask 741
# Generating mask 742
# Saving mask 742
# Generating mask 743
# Saving mask 743
# Generating mask 744
# Saving mask 744
# Generating mask 745
# Saving mask 745
# Generating mask 746
# Saving mask 746
# Generating mask 747
# Saving mask 747
# Generating mask 748
# Saving mask 748
# Generating mask 749
# Saving mask 749
# Generating mask 750
# Saving mask 750
# Generating mask 751
# Saving mask 751
# Generating mask 752
# Saving mask 752
# Generating mask 753
# Saving mask 753
# Generating mask 754
# Saving mask 754
# Generating mask 755
# Saving mask 755
# Generating mask 756
# Saving mask 756
# Generating mask 757
# Saving mask 757
# Generating mask 758
# Saving mask 758
# Generating mask 759
# Saving mask 759
# Generating mask 760
# Saving mask 760
# Generating mask 761
# Saving mask 761
# Generating mask 762
# Saving mask 762
# Generating mask 763
# Saving mask 763
# Generating mask 764
# Saving mask 764
# Generating mask 765
# Saving mask 765
# Generating mask 766
# Saving mask 766
# Generating mask 767
# Saving mask 767
# Generating mask 768
# Saving mask 768
# Generating mask 769
# Saving mask 769
# Generating mask 770
# Saving mask 770
# Generating mask 771
# Saving mask 771
# Generating mask 772
# Saving mask 772
# Generating mask 773
# Saving mask 773
# Generating mask 774
# Saving mask 774
# Generating mask 775
# Saving mask 775
# Generating mask 776
# Saving mask 776
# Generating mask 777
# Saving mask 777
# Generating mask 778
# Saving mask 778
# Generating mask 779
# Saving mask 779
# Generating mask 780
# Saving mask 780
# Generating mask 781
# Saving mask 781
# Generating mask 782
# Saving mask 782
# Generating mask 783
# Saving mask 783
# Generating mask 784
# Saving mask 784
# Generating mask 785
# Saving mask 785
# Generating mask 786
# Saving mask 786
# Generating mask 787
# Saving mask 787
# Generating mask 788
# Saving mask 788
# Generating mask 789
# Saving mask 789
# Generating mask 790
# Saving mask 790
# Generating mask 791
# Saving mask 791
# Generating mask 792
# Saving mask 792
# Generating mask 793
# Saving mask 793
# Generating mask 794
# Saving mask 794
# Generating mask 795
# Saving mask 795
# Generating mask 796
# Saving mask 796
# Generating mask 797
# Saving mask 797
# Generating mask 798
# Saving mask 798
# Generating mask 799
# Saving mask 799
# Generating mask 800
# Saving mask 800
# Generating mask 801
# Saving mask 801
# Generating mask 802
# Saving mask 802
# Generating mask 803
# Saving mask 803
# Generating mask 804
# Saving mask 804
# Generating mask 805
# Saving mask 805
# Generating mask 806
# Saving mask 806
# Generating mask 807
# Saving mask 807
# Generating mask 808
# Saving mask 808
# Generating mask 809
# Saving mask 809
# Generating mask 810
# Saving mask 810
# Generating mask 811
# Saving mask 811
# Generating mask 812
# Saving mask 812
# Generating mask 813
# Saving mask 813
# Generating mask 814
# Saving mask 814
# Generating mask 815
# Saving mask 815
# Generating mask 816
# Saving mask 816
# Generating mask 817
# Saving mask 817
# Generating mask 818
# Saving mask 818
# Generating mask 819
# Saving mask 819
# Generating mask 820
# Saving mask 820
# Generating mask 821
# Saving mask 821
# Generating mask 822
# Saving mask 822
# Generating mask 823
# Saving mask 823
# Generating mask 824
# Saving mask 824
# Generating mask 825
# Saving mask 825
# Generating mask 826
# Saving mask 826
# Generating mask 827
# Saving mask 827
# Generating mask 828
# Saving mask 828
# Generating mask 829
# Saving mask 829
# Generating mask 830
# Saving mask 830
# Generating mask 831
# Saving mask 831
# Generating mask 832
# Saving mask 832
# Generating mask 833
# Saving mask 833
# Generating mask 834
# Saving mask 834
# Generating mask 835
# Saving mask 835
# Generating mask 836
# Saving mask 836
# Generating mask 837
# Saving mask 837
# Generating mask 838
# Saving mask 838
# Generating mask 839
# Saving mask 839
# Generating mask 840
# Saving mask 840
# Generating mask 841
# Saving mask 841
# Generating mask 842
# Saving mask 842
# Generating mask 843
# Saving mask 843
# Generating mask 844
# Saving mask 844
# Generating mask 845
# Saving mask 845
# Generating mask 846
# Saving mask 846
# Generating mask 847
# Saving mask 847
# Generating mask 848
# Saving mask 848
# Generating mask 849
# Saving mask 849
# Generating mask 850
# Saving mask 850
# Generating mask 851
# Saving mask 851
# Generating mask 852
# Saving mask 852
# Generating mask 853
# Saving mask 853
# Generating mask 854
# Saving mask 854
# Generating mask 855
# Saving mask 855
# Generating mask 856
# Saving mask 856
# Generating mask 857
# Saving mask 857
# Generating mask 858
# Saving mask 858
# Generating mask 859
# Saving mask 859
# Generating mask 860
# Saving mask 860
# Generating mask 861
# Saving mask 861
# Generating mask 862
# Saving mask 862
# Generating mask 863
# Saving mask 863
# Generating mask 864
# Saving mask 864
# Generating mask 865
# Saving mask 865
# Generating mask 866
# Saving mask 866
# Generating mask 867
# Saving mask 867
# Generating mask 868
# Saving mask 868
# Generating mask 869
# Saving mask 869
# Generating mask 870
# Saving mask 870
# Generating mask 871
# Saving mask 871
# Generating mask 872
# Saving mask 872
# Generating mask 873
# Saving mask 873
# Generating mask 874
# Saving mask 874
# Generating mask 875
# Saving mask 875
# Generating mask 876
# Saving mask 876
# Generating mask 877
# Saving mask 877
# Generating mask 878
# Saving mask 878
# Generating mask 879
# Saving mask 879
# Generating mask 880
# Saving mask 880
# Generating mask 881
# Saving mask 881
# Generating mask 882
# Saving mask 882
# Generating mask 883
# Saving mask 883
# Generating mask 884
# Saving mask 884
# Generating mask 885
# Saving mask 885
# Generating mask 886
# Saving mask 886
# Generating mask 887
# Saving mask 887
# Generating mask 888
# Saving mask 888
# Generating mask 889
# Saving mask 889
# Generating mask 890
# Saving mask 890
# Generating mask 891
# Saving mask 891
# Generating mask 892
# Saving mask 892
# Generating mask 893
# Saving mask 893
# Generating mask 894
# Saving mask 894
# Generating mask 895
# Saving mask 895
# Generating mask 896
# Saving mask 896
# Generating mask 897
# Saving mask 897
# Generating mask 898
# Saving mask 898
# Generating mask 899
# Saving mask 899
# Generating mask 900
# Saving mask 900
# Generating mask 901
# Saving mask 901
# Generating mask 902
# Saving mask 902
# Generating mask 903
# Saving mask 903
# Generating mask 904
# Saving mask 904
# Generating mask 905
# Saving mask 905
# Generating mask 906
# Saving mask 906
# Generating mask 907
# Saving mask 907
# Generating mask 908
# Saving mask 908
# Generating mask 909
# Saving mask 909
# Generating mask 910
# Saving mask 910
# Generating mask 911
# Saving mask 911
# Generating mask 912
# Saving mask 912
# Generating mask 913
# Saving mask 913
# Generating mask 914
# Saving mask 914
# Generating mask 915
# Saving mask 915
# Generating mask 916
# Saving mask 916
# Generating mask 917
# Saving mask 917
# Generating mask 918
# Saving mask 918
# Generating mask 919
# Saving mask 919
# Generating mask 920
# Saving mask 920
# Generating mask 921
# Saving mask 921
# Generating mask 922
# Saving mask 922
# Generating mask 923
# Saving mask 923
# Generating mask 924
# Saving mask 924
# Generating mask 925
# Saving mask 925
# Generating mask 926
# Saving mask 926
# Generating mask 927
# Saving mask 927
# Generating mask 928
# Saving mask 928
# Generating mask 929
# Saving mask 929
# Generating mask 930
# Saving mask 930
# Generating mask 931
# Saving mask 931
# Generating mask 932
# Saving mask 932
# Generating mask 933
# Saving mask 933
# Generating mask 934
# Saving mask 934
# Generating mask 935
# Saving mask 935
# Generating mask 936
# Saving mask 936
# Generating mask 937
# Saving mask 937
# Generating mask 938
# Saving mask 938
# Generating mask 939
# Saving mask 939
# Generating mask 940
# Saving mask 940
# Generating mask 941
# Saving mask 941
# Generating mask 942
# Saving mask 942
# Generating mask 943
# Saving mask 943
# Generating mask 944
# Saving mask 944
# Generating mask 945
# Saving mask 945
# Generating mask 946
# Saving mask 946
# Generating mask 947
# Saving mask 947
# Generating mask 948
# Saving mask 948
# Generating mask 949
# Saving mask 949
# Generating mask 950
# Saving mask 950
# Generating mask 951
# Saving mask 951
# Generating mask 952
# Saving mask 952
# Generating mask 953
# Saving mask 953
# Generating mask 954
# Saving mask 954
# Generating mask 955
# Saving mask 955
# Generating mask 956
# Saving mask 956
# Generating mask 957
# Saving mask 957
# Generating mask 958
# Saving mask 958
# Generating mask 959
# Saving mask 959
# Generating mask 960
# Saving mask 960
# Generating mask 961
# Saving mask 961
# Generating mask 962
# Saving mask 962
# Generating mask 963
# Saving mask 963
# Generating mask 964
# Saving mask 964
# Generating mask 965
# Saving mask 965
# Generating mask 966
# Saving mask 966
# Generating mask 967
# Saving mask 967
# Generating mask 968
# Saving mask 968
# Generating mask 969
# Saving mask 969
# Generating mask 970
# Saving mask 970
# Generating mask 971
# Saving mask 971
# Generating mask 972
# Saving mask 972
# Generating mask 973
# Saving mask 973
# Generating mask 974
# Saving mask 974
# Generating mask 975
# Saving mask 975
# Generating mask 976
# Saving mask 976
# Generating mask 977
# Saving mask 977
# Generating mask 978
# Saving mask 978
# Generating mask 979
# Saving mask 979
# Generating mask 980
# Saving mask 980
# Generating mask 981
# Saving mask 981
# Generating mask 982
# Saving mask 982
# Generating mask 983
# Saving mask 983
# Generating mask 984
# Saving mask 984
# Generating mask 985
# Saving mask 985
# Generating mask 986
# Saving mask 986
# Generating mask 987
# Saving mask 987
# Generating mask 988
# Saving mask 988
# Generating mask 989
# Saving mask 989
# Generating mask 990
# Saving mask 990
# Generating mask 991
# Saving mask 991
# Generating mask 992
# Saving mask 992
# Generating mask 993
# Saving mask 993
# Generating mask 994
# Saving mask 994
# Generating mask 995
# Saving mask 995
# Generating mask 996
# Saving mask 996
# Generating mask 997
# Saving mask 997
# Generating mask 998
# Saving mask 998
# Generating mask 999
# Saving mask 999
# Generating mask 1000
# Saving mask 1000
# Generating mask 1001
# Saving mask 1001
# Generating mask 1002
# Saving mask 1002
# Generating mask 1003
# Saving mask 1003
# Generating mask 1004
# Saving mask 1004
# Generating mask 1005
# Saving mask 1005
# Generating mask 1006
# Saving mask 1006
# Generating mask 1007
# Saving mask 1007
# Generating mask 1008
# Saving mask 1008
# Generating mask 1009
# Saving mask 1009
# Generating mask 1010
# Saving mask 1010
# Generating mask 1011
# Saving mask 1011
# Generating mask 1012
# Saving mask 1012
# Generating mask 1013
# Saving mask 1013
# Generating mask 1014
# Saving mask 1014
# Generating mask 1015
# Saving mask 1015
# Generating mask 1016
# Saving mask 1016
# Generating mask 1017
# Saving mask 1017
# Generating mask 1018
# Saving mask 1018
# Generating mask 1019
# Saving mask 1019
# Generating mask 1020
# Saving mask 1020
# Generating mask 1021
# Saving mask 1021
# Generating mask 1022
# Saving mask 1022
# Generating mask 1023
# Saving mask 1023
# Generating mask 1024
# Saving mask 1024
# Generating mask 1025
# Saving mask 1025
# Generating mask 1026
# Saving mask 1026
# Generating mask 1027
# Saving mask 1027
# Generating mask 1028
# Saving mask 1028
# Generating mask 1029
# Saving mask 1029
# Generating mask 1030
# Saving mask 1030
# Generating mask 1031
# Saving mask 1031
# Generating mask 1032
# Saving mask 1032
# Generating mask 1033
# Saving mask 1033
# Generating mask 1034
# Saving mask 1034
# Generating mask 1035
# Saving mask 1035
# Generating mask 1036
# Saving mask 1036
# Generating mask 1037
# Saving mask 1037
# Generating mask 1038
# Saving mask 1038
# Generating mask 1039
# Saving mask 1039
# Generating mask 1040
# Saving mask 1040
# Generating mask 1041
# Saving mask 1041
# Generating mask 1042
# Saving mask 1042
# Generating mask 1043
# Saving mask 1043
# Generating mask 1044
# Saving mask 1044
# Generating mask 1045
# Saving mask 1045
# Generating mask 1046
# Saving mask 1046
# Generating mask 1047
# Saving mask 1047
# Generating mask 1048
# Saving mask 1048
# Generating mask 1049
# Saving mask 1049
# Generating mask 1050
# Saving mask 1050
# Generating mask 1051
# Saving mask 1051
# Generating mask 1052
# Saving mask 1052
# Generating mask 1053
# Saving mask 1053
# Generating mask 1054
# Saving mask 1054
# Generating mask 1055
# Saving mask 1055
# Generating mask 1056
# Saving mask 1056
# Generating mask 1057
# Saving mask 1057
# Generating mask 1058
# Saving mask 1058
# Generating mask 1059
# Saving mask 1059
# Generating mask 1060
# Saving mask 1060
# Generating mask 1061
# Saving mask 1061
# Generating mask 1062
# Saving mask 1062
# Generating mask 1063
# Saving mask 1063
# Generating mask 1064
# Saving mask 1064
# Generating mask 1065
# Saving mask 1065
# Generating mask 1066
# Saving mask 1066
# Generating mask 1067
# Saving mask 1067
# Generating mask 1068
# Saving mask 1068
# Generating mask 1069
# Saving mask 1069
# Generating mask 1070
# Saving mask 1070
# Generating mask 1071
# Saving mask 1071
# Generating mask 1072
# Saving mask 1072
# Generating mask 1073
# Saving mask 1073
# Generating mask 1074
# Saving mask 1074
# Generating mask 1075
# Saving mask 1075
# Generating mask 1076
# Saving mask 1076
# Generating mask 1077
# Saving mask 1077
# Generating mask 1078
# Saving mask 1078
# Generating mask 1079
# Saving mask 1079
# Generating mask 1080
# Saving mask 1080
# Generating mask 1081
# Saving mask 1081
# Generating mask 1082
# Saving mask 1082
# Generating mask 1083
# Saving mask 1083
# Generating mask 1084
# Saving mask 1084
# Generating mask 1085
# Saving mask 1085
# Generating mask 1086
# Saving mask 1086
# Generating mask 1087
# Saving mask 1087
# Generating mask 1088
# Saving mask 1088
# Generating mask 1089
# Saving mask 1089
# Generating mask 1090
# Saving mask 1090
# Generating mask 1091
# Saving mask 1091
# Generating mask 1092
# Saving mask 1092
# Generating mask 1093
# Saving mask 1093
# Generating mask 1094
# Saving mask 1094
# Generating mask 1095
# Saving mask 1095
# Generating mask 1096
# Saving mask 1096
# Generating mask 1097
# Saving mask 1097
# Generating mask 1098
# Saving mask 1098
# Generating mask 1099
# Saving mask 1099
# Generating mask 1100
# Saving mask 1100
# Generating mask 1101
# Saving mask 1101
# Generating mask 1102
# Saving mask 1102
# Generating mask 1103
# Saving mask 1103
# Generating mask 1104
# Saving mask 1104
# Generating mask 1105
# Saving mask 1105
# Generating mask 1106
# Saving mask 1106
# Generating mask 1107
# Saving mask 1107
# Generating mask 1108
# Saving mask 1108
# Generating mask 1109
# Saving mask 1109
# Generating mask 1110
# Saving mask 1110
# Generating mask 1111
# Saving mask 1111
# Generating mask 1112
# Saving mask 1112
# Generating mask 1113
# Saving mask 1113
# Generating mask 1114
# Saving mask 1114
# Generating mask 1115
# Saving mask 1115
# Generating mask 1116
# Saving mask 1116
# Generating mask 1117
# Saving mask 1117
# Generating mask 1118
# Saving mask 1118
# Generating mask 1119
# Saving mask 1119
# Generating mask 1120
# Saving mask 1120
# Generating mask 1121
# Saving mask 1121
# Generating mask 1122
# Saving mask 1122
# Generating mask 1123
# Saving mask 1123
# Generating mask 1124
# Saving mask 1124
# Generating mask 1125
# Saving mask 1125
# Generating mask 1126
# Saving mask 1126
# Generating mask 1127
# Saving mask 1127
# Generating mask 1128
# Saving mask 1128
# Generating mask 1129
# Saving mask 1129
# Generating mask 1130
# Saving mask 1130
# Generating mask 1131
# Saving mask 1131
# Generating mask 1132
# Saving mask 1132
# Generating mask 1133
# Saving mask 1133
# Generating mask 1134
# Saving mask 1134
# Generating mask 1135
# Saving mask 1135
# Generating mask 1136
# Saving mask 1136
# Generating mask 1137
# Saving mask 1137
# Generating mask 1138
# Saving mask 1138
# Generating mask 1139
# Saving mask 1139
# Generating mask 1140
# Saving mask 1140
# Generating mask 1141
# Saving mask 1141
# Generating mask 1142
# Saving mask 1142
# Generating mask 1143
# Saving mask 1143
# Generating mask 1144
# Saving mask 1144
# Generating mask 1145
# Saving mask 1145
# Generating mask 1146
# Saving mask 1146
# Generating mask 1147
# Saving mask 1147
# Generating mask 1148
# Saving mask 1148
# Generating mask 1149
# Saving mask 1149
# Generating mask 1150
# Saving mask 1150
# Generating mask 1151
# Saving mask 1151
# Generating mask 1152
# Saving mask 1152
# Generating mask 1153
# Saving mask 1153
# Generating mask 1154
# Saving mask 1154
# Generating mask 1155
# Saving mask 1155
# Generating mask 1156
# Saving mask 1156
# Generating mask 1157
# Saving mask 1157
# Generating mask 1158
# Saving mask 1158
# Generating mask 1159
# Saving mask 1159
# Generating mask 1160
# Saving mask 1160
# Generating mask 1161
# Saving mask 1161
# Generating mask 1162
# Saving mask 1162
# Generating mask 1163
# Saving mask 1163
# Generating mask 1164
# Saving mask 1164
# Generating mask 1165
# Saving mask 1165
# Generating mask 1166
# Saving mask 1166
# Generating mask 1167
# Saving mask 1167
# Generating mask 1168
# Saving mask 1168
# Generating mask 1169
# Saving mask 1169
# Generating mask 1170
# Saving mask 1170
# Generating mask 1171
# Saving mask 1171
# Generating mask 1172
# Saving mask 1172
# Generating mask 1173
# Saving mask 1173
# Generating mask 1174
# Saving mask 1174
# Generating mask 1175
# Saving mask 1175
# Generating mask 1176
# Saving mask 1176
# Generating mask 1177
# Saving mask 1177
# Generating mask 1178
# Saving mask 1178
# Generating mask 1179
# Saving mask 1179
# Generating mask 1180
# Saving mask 1180
# Generating mask 1181
# Saving mask 1181
# Generating mask 1182
# Saving mask 1182
# Generating mask 1183
# Saving mask 1183
# Generating mask 1184
# Saving mask 1184
# Generating mask 1185
# Saving mask 1185
# Generating mask 1186
# Saving mask 1186
# Generating mask 1187
# Saving mask 1187
# Generating mask 1188
# Saving mask 1188
# Generating mask 1189
# Saving mask 1189
# Generating mask 1190
# Saving mask 1190
# Generating mask 1191
# Saving mask 1191
# Generating mask 1192
# Saving mask 1192
# Generating mask 1193
# Saving mask 1193
# Generating mask 1194
# Saving mask 1194
# Generating mask 1195
# Saving mask 1195
# Generating mask 1196
# Saving mask 1196
# Generating mask 1197
# Saving mask 1197
# Generating mask 1198
# Saving mask 1198
# Generating mask 1199
# Saving mask 1199
# Generating mask 1200
# Saving mask 1200
# Generating mask 1201
# Saving mask 1201
# Generating mask 1202
# Saving mask 1202
# Generating mask 1203
# Saving mask 1203
# Generating mask 1204
# Saving mask 1204
# Generating mask 1205
# Saving mask 1205
# Generating mask 1206
# Saving mask 1206
# Generating mask 1207
# Saving mask 1207
# Generating mask 1208
# Saving mask 1208
# Generating mask 1209
# Saving mask 1209
# Generating mask 1210
# Saving mask 1210
# Generating mask 1211
# Saving mask 1211
# Generating mask 1212
# Saving mask 1212
# Generating mask 1213
# Saving mask 1213
# Generating mask 1214
# Saving mask 1214
# Generating mask 1215
# Saving mask 1215
# Generating mask 1216
# Saving mask 1216
# Generating mask 1217
# Saving mask 1217
# Generating mask 1218
# Saving mask 1218
# Generating mask 1219
# Saving mask 1219
# Generating mask 1220
# Saving mask 1220
# Generating mask 1221
# Saving mask 1221
# Generating mask 1222
# Saving mask 1222
# Generating mask 1223
# Saving mask 1223
# Generating mask 1224
# Saving mask 1224
# Generating mask 1225
# Saving mask 1225
# Generating mask 1226
# Saving mask 1226
# Generating mask 1227
# Saving mask 1227
# Generating mask 1228
# Saving mask 1228
# Generating mask 1229
# Saving mask 1229
# Generating mask 1230
# Saving mask 1230
# Generating mask 1231
# Saving mask 1231
# Generating mask 1232
# Saving mask 1232
# Generating mask 1233
# Saving mask 1233
# Generating mask 1234
# Saving mask 1234
# Generating mask 1235
# Saving mask 1235
# Generating mask 1236
# Saving mask 1236
# Generating mask 1237
# Saving mask 1237
# Generating mask 1238
# Saving mask 1238
# Generating mask 1239
# Saving mask 1239
# Generating mask 1240
# Saving mask 1240
# Generating mask 1241
# Saving mask 1241
# Generating mask 1242
# Saving mask 1242
# Generating mask 1243
# Saving mask 1243
# Generating mask 1244
# Saving mask 1244
# Generating mask 1245
# Saving mask 1245
# Generating mask 1246
# Saving mask 1246
# Generating mask 1247
# Saving mask 1247
# Generating mask 1248
# Saving mask 1248
# Generating mask 1249
# Saving mask 1249
# Generating mask 1250
# Saving mask 1250
# Generating mask 1251
# Saving mask 1251
# Generating mask 1252
# Saving mask 1252
# Generating mask 1253
# Saving mask 1253
# Generating mask 1254
# Saving mask 1254
# Generating mask 1255
# Saving mask 1255
# Generating mask 1256
# Saving mask 1256
# Generating mask 1257
# Saving mask 1257
# Generating mask 1258
# Saving mask 1258
# Generating mask 1259
# Saving mask 1259
# Generating mask 1260
# Saving mask 1260
# Generating mask 1261
# Saving mask 1261
# Generating mask 1262
# Saving mask 1262
# Generating mask 1263
# Saving mask 1263
# Generating mask 1264
# Saving mask 1264
# Generating mask 1265
# Saving mask 1265
# Generating mask 1266
# Saving mask 1266
# Generating mask 1267
# Saving mask 1267
# Generating mask 1268
# Saving mask 1268
# Generating mask 1269
# Saving mask 1269
# Generating mask 1270
# Saving mask 1270
# Generating mask 1271
# Saving mask 1271
# Generating mask 1272
# Saving mask 1272
# Generating mask 1273
# Saving mask 1273
# Generating mask 1274
# Saving mask 1274
# Generating mask 1275
# Saving mask 1275
# Generating mask 1276
# Saving mask 1276
# Generating mask 1277
# Saving mask 1277
# Generating mask 1278
# Saving mask 1278
# Generating mask 1279
# Saving mask 1279
# Generating mask 1280
# Saving mask 1280
# Generating mask 1281
# Saving mask 1281
# Generating mask 1282
# Saving mask 1282
# Generating mask 1283
# Saving mask 1283
# Generating mask 1284
# Saving mask 1284
# Generating mask 1285
# Saving mask 1285
# Generating mask 1286
# Saving mask 1286
# Generating mask 1287
# Saving mask 1287
# Generating mask 1288
# Saving mask 1288
# Generating mask 1289
# Saving mask 1289
# Generating mask 1290
# Saving mask 1290
# Generating mask 1291
# Saving mask 1291
# Generating mask 1292
# Saving mask 1292
# Generating mask 1293
# Saving mask 1293
# Generating mask 1294
# Saving mask 1294
# Generating mask 1295
# Saving mask 1295
# Generating mask 1296
# Saving mask 1296
# Generating mask 1297
# Saving mask 1297
# Generating mask 1298
# Saving mask 1298
# Generating mask 1299
# Saving mask 1299
# Generating mask 1300
# Saving mask 1300
# Generating mask 1301
# Saving mask 1301
# Generating mask 1302
# Saving mask 1302
# Generating mask 1303
# Saving mask 1303
# Generating mask 1304
# Saving mask 1304
# Generating mask 1305
# Saving mask 1305
# Generating mask 1306
# Saving mask 1306
# Generating mask 1307
# Saving mask 1307
# Generating mask 1308
# Saving mask 1308
# Generating mask 1309
# Saving mask 1309
# Generating mask 1310
# Saving mask 1310
# Generating mask 1311
# Saving mask 1311
# Generating mask 1312
# Saving mask 1312
# Generating mask 1313
# Saving mask 1313
# Generating mask 1314
# Saving mask 1314
# Generating mask 1315
# Saving mask 1315
# Generating mask 1316
# Saving mask 1316
# Generating mask 1317
# Saving mask 1317
# Generating mask 1318
# Saving mask 1318
# Generating mask 1319
# Saving mask 1319
# ...
# Saving mask 19600
# Generating mask 19601
# Saving mask 19601
# Generating mask 19602
# Saving mask 19602
# Generating mask 19603
# Saving mask 19603
# Generating mask 19604
# Saving mask 19604
# Generating mask 19605
# Saving mask 19605
# Generating mask 19606
# Saving mask 19606
# Generating mask 19607
# Saving mask 19607
# Generating mask 19608
# Saving mask 19608
# Generating mask 19609
# Saving mask 19609
# Generating mask 19610
# Saving mask 19610
# Generating mask 19611
# Saving mask 19611
# Generating mask 19612
# Saving mask 19612
# Generating mask 19613
# Saving mask 19613
# Generating mask 19614
# Saving mask 19614
# Generating mask 19615
# Saving mask 19615
# Generating mask 19616
# Saving mask 19616
# Generating mask 19617
# Saving mask 19617
# Generating mask 19618
# Saving mask 19618
# Generating mask 19619
# Saving mask 19619
# Generating mask 19620
# Saving mask 19620
# Generating mask 19621
# Saving mask 19621
# Generating mask 19622
# Saving mask 19622
# Generating mask 19623
# Saving mask 19623
# Generating mask 19624
# Saving mask 19624
# Generating mask 19625
# Saving mask 19625
# Generating mask 19626
# Saving mask 19626
# Generating mask 19627
# Saving mask 19627
# Generating mask 19628
# Saving mask 19628
# Generating mask 19629
# Saving mask 19629
# Generating mask 19630
# Saving mask 19630
# Generating mask 19631
# Saving mask 19631
# Generating mask 19632
# Saving mask 19632
# Generating mask 19633
# Saving mask 19633
# Generating mask 19634
# Saving mask 19634
# Generating mask 19635
# Saving mask 19635
# Generating mask 19636
# Saving mask 19636
# Generating mask 19637
# Saving mask 19637
# Generating mask 19638
# Saving mask 19638
# Generating mask 19639
# Saving mask 19639
# Generating mask 19640
# Saving mask 19640
# Generating mask 19641
# Saving mask 19641
# Generating mask 19642
# Saving mask 19642
# Generating mask 19643
# Saving mask 19643
# Generating mask 19644
# Saving mask 19644
# Generating mask 19645
# Saving mask 19645
# Generating mask 19646
# Saving mask 19646
# Generating mask 19647
# Saving mask 19647
# Generating mask 19648
# Saving mask 19648
# Generating mask 19649
# Saving mask 19649
# Generating mask 19650
# Saving mask 19650
# Generating mask 19651
# Saving mask 19651
# Generating mask 19652
# Saving mask 19652
# Generating mask 19653
# Saving mask 19653
# Generating mask 19654
# Saving mask 19654
# Generating mask 19655
# Saving mask 19655
# Generating mask 19656
# Saving mask 19656
# Generating mask 19657
# Saving mask 19657
# Generating mask 19658
# Saving mask 19658
# Generating mask 19659
# Saving mask 19659
# Generating mask 19660
# Saving mask 19660
# Generating mask 19661
# Saving mask 19661
# Generating mask 19662
# Saving mask 19662
# Generating mask 19663
# Saving mask 19663
# Generating mask 19664
# Saving mask 19664
# Generating mask 19665
# Saving mask 19665
# Generating mask 19666
# Saving mask 19666
# Generating mask 19667
# Saving mask 19667
# Generating mask 19668
# Saving mask 19668
# Generating mask 19669
# Saving mask 19669
# Generating mask 19670
# Saving mask 19670
# Generating mask 19671
# Saving mask 19671
# Generating mask 19672
# Saving mask 19672
# Generating mask 19673
# Saving mask 19673
# Generating mask 19674
# Saving mask 19674
# Generating mask 19675
# Saving mask 19675
# Generating mask 19676
# Saving mask 19676
# Generating mask 19677
# Saving mask 19677
# Generating mask 19678
# Saving mask 19678
# Generating mask 19679
# Saving mask 19679
# Generating mask 19680
# Saving mask 19680
# Generating mask 19681
# Saving mask 19681
# Generating mask 19682
# Saving mask 19682
# Generating mask 19683
# Saving mask 19683
# Generating mask 19684
# Saving mask 19684
# Generating mask 19685
# Saving mask 19685
# Generating mask 19686
# Saving mask 19686
# Generating mask 19687
# Saving mask 19687
# Generating mask 19688
# Saving mask 19688
# Generating mask 19689
# Saving mask 19689
# Generating mask 19690
# Saving mask 19690
# Generating mask 19691
# Saving mask 19691
# Generating mask 19692
# Saving mask 19692
# Generating mask 19693
# Saving mask 19693
# Generating mask 19694
# Saving mask 19694
# Generating mask 19695
# Saving mask 19695
# Generating mask 19696
# Saving mask 19696
# Generating mask 19697
# Saving mask 19697
# Generating mask 19698
# Saving mask 19698
# Generating mask 19699
# Saving mask 19699
# Generating mask 19700
# Saving mask 19700
# Generating mask 19701
# Saving mask 19701
# Generating mask 19702
# Saving mask 19702
# Generating mask 19703
# Saving mask 19703
# Generating mask 19704
# Saving mask 19704
# Generating mask 19705
# Saving mask 19705
# Generating mask 19706
# Saving mask 19706
# Generating mask 19707
# Saving mask 19707
# Generating mask 19708
# Saving mask 19708
# Generating mask 19709
# Saving mask 19709
# Generating mask 19710
# Saving mask 19710
# Generating mask 19711
# Saving mask 19711
# Generating mask 19712
# Saving mask 19712
# Generating mask 19713
# Saving mask 19713
# Generating mask 19714
# Saving mask 19714
# Generating mask 19715
# Saving mask 19715
# Generating mask 19716
# Saving mask 19716
# Generating mask 19717
# Saving mask 19717
# Generating mask 19718
# Saving mask 19718
# Generating mask 19719
# Saving mask 19719
# Generating mask 19720
# Saving mask 19720
# Generating mask 19721
# Saving mask 19721
# Generating mask 19722
# Saving mask 19722
# Generating mask 19723
# Saving mask 19723
# Generating mask 19724
# Saving mask 19724
# Generating mask 19725
# Saving mask 19725
# Generating mask 19726
# Saving mask 19726
# Generating mask 19727
# Saving mask 19727
# Generating mask 19728
# Saving mask 19728
# Generating mask 19729
# Saving mask 19729
# Generating mask 19730
# Saving mask 19730
# Generating mask 19731
# Saving mask 19731
# Generating mask 19732
# Saving mask 19732
# Generating mask 19733
# Saving mask 19733
# Generating mask 19734
# Saving mask 19734
# Generating mask 19735
# Saving mask 19735
# Generating mask 19736
# Saving mask 19736
# Generating mask 19737
# Saving mask 19737
# Generating mask 19738
# Saving mask 19738
# Generating mask 19739
# Saving mask 19739
# Generating mask 19740
# Saving mask 19740
# Generating mask 19741
# Saving mask 19741
# Generating mask 19742
# Saving mask 19742
# Generating mask 19743
# Saving mask 19743
# Generating mask 19744
# Saving mask 19744
# Generating mask 19745
# Saving mask 19745
# Generating mask 19746
# Saving mask 19746
# Generating mask 19747
# Saving mask 19747
# Generating mask 19748
# Saving mask 19748
# Generating mask 19749
# Saving mask 19749
# Generating mask 19750
# Saving mask 19750
# Generating mask 19751
# Saving mask 19751
# Generating mask 19752
# Saving mask 19752
# Generating mask 19753
# Saving mask 19753
# Generating mask 19754
# Saving mask 19754
# Generating mask 19755
# Saving mask 19755
# Generating mask 19756
# Saving mask 19756
# Generating mask 19757
# Saving mask 19757
# Generating mask 19758
# Saving mask 19758
# Generating mask 19759
# Saving mask 19759
# Generating mask 19760
# Saving mask 19760
# Generating mask 19761
# Saving mask 19761
# Generating mask 19762
# Saving mask 19762
# Generating mask 19763
# Saving mask 19763
# Generating mask 19764
# Saving mask 19764
# Generating mask 19765
# Saving mask 19765
# Generating mask 19766
# Saving mask 19766
# Generating mask 19767
# Saving mask 19767
# Generating mask 19768
# Saving mask 19768
# Generating mask 19769
# Saving mask 19769
# Generating mask 19770
# Saving mask 19770
# Generating mask 19771
# Saving mask 19771
# Generating mask 19772
# Saving mask 19772
# Generating mask 19773
# Saving mask 19773
# Generating mask 19774
# Saving mask 19774
# Generating mask 19775
# Saving mask 19775
# Generating mask 19776
# Saving mask 19776
# Generating mask 19777
# Saving mask 19777
# Generating mask 19778
# Saving mask 19778
# Generating mask 19779
# Saving mask 19779
# Generating mask 19780
# Saving mask 19780
# Generating mask 19781
# Saving mask 19781
# Generating mask 19782
# Saving mask 19782
# Generating mask 19783
# Saving mask 19783
# Generating mask 19784
# Saving mask 19784
# Generating mask 19785
# Saving mask 19785
# Generating mask 19786
# Saving mask 19786
# Generating mask 19787
# Saving mask 19787
# Generating mask 19788
# Saving mask 19788
# Generating mask 19789
# Saving mask 19789
# Generating mask 19790
# Saving mask 19790
# Generating mask 19791
# Saving mask 19791
# Generating mask 19792
# Saving mask 19792
# Generating mask 19793
# Saving mask 19793
# Generating mask 19794
# Saving mask 19794
# Generating mask 19795
# Saving mask 19795
# Generating mask 19796
# Saving mask 19796
# Generating mask 19797
# Saving mask 19797
# Generating mask 19798
# Saving mask 19798
# Generating mask 19799
# Saving mask 19799
# Generating mask 19800
# Saving mask 19800
# Generating mask 19801
# Saving mask 19801
# Generating mask 19802
# Saving mask 19802
# Generating mask 19803
# Saving mask 19803
# Generating mask 19804
# Saving mask 19804
# Generating mask 19805
# Saving mask 19805
# Generating mask 19806
# Saving mask 19806
# Generating mask 19807
# Saving mask 19807
# Generating mask 19808
# Saving mask 19808
# Generating mask 19809
# Saving mask 19809
# Generating mask 19810
# Saving mask 19810
# Generating mask 19811
# Saving mask 19811
# Generating mask 19812
# Saving mask 19812
# Generating mask 19813
# Saving mask 19813
# Generating mask 19814
# Saving mask 19814
# Generating mask 19815
# Saving mask 19815
# Generating mask 19816
# Saving mask 19816
# Generating mask 19817
# Saving mask 19817
# Generating mask 19818
# Saving mask 19818
# Generating mask 19819
# Saving mask 19819
# Generating mask 19820
# Saving mask 19820
# Generating mask 19821
# Saving mask 19821
# Generating mask 19822
# Saving mask 19822
# Generating mask 19823
# Saving mask 19823
# Generating mask 19824
# Saving mask 19824
# Generating mask 19825
# Saving mask 19825
# Generating mask 19826
# Saving mask 19826
# Generating mask 19827
# Saving mask 19827
# Generating mask 19828
# Saving mask 19828
# Generating mask 19829
# Saving mask 19829
# Generating mask 19830
# Saving mask 19830
# Generating mask 19831
# Saving mask 19831
# Generating mask 19832
# Saving mask 19832
# Generating mask 19833
# Saving mask 19833
# Generating mask 19834
# Saving mask 19834
# Generating mask 19835
# Saving mask 19835
# Generating mask 19836
# Saving mask 19836
# Generating mask 19837
# Saving mask 19837
# Generating mask 19838
# Saving mask 19838
# Generating mask 19839
# Saving mask 19839
# Generating mask 19840
# Saving mask 19840
# Generating mask 19841
# Saving mask 19841
# Generating mask 19842
# Saving mask 19842
# Generating mask 19843
# Saving mask 19843
# Generating mask 19844
# Saving mask 19844
# Generating mask 19845
# Saving mask 19845
# Generating mask 19846
# Saving mask 19846
# Generating mask 19847
# Saving mask 19847
# Generating mask 19848
# Saving mask 19848
# Generating mask 19849
# Saving mask 19849
# Generating mask 19850
# Saving mask 19850
# Generating mask 19851
# Saving mask 19851
# Generating mask 19852
# Saving mask 19852
# Generating mask 19853
# Saving mask 19853
# Generating mask 19854
# Saving mask 19854
# Generating mask 19855
# Saving mask 19855
# Generating mask 19856
# Saving mask 19856
# Generating mask 19857
# Saving mask 19857
# Generating mask 19858
# Saving mask 19858
# Generating mask 19859
# Saving mask 19859
# Generating mask 19860
# Saving mask 19860
# Generating mask 19861
# Saving mask 19861
# Generating mask 19862
# Saving mask 19862
# Generating mask 19863
# Saving mask 19863
# Generating mask 19864
# Saving mask 19864
# Generating mask 19865
# Saving mask 19865
# Generating mask 19866
# Saving mask 19866
# Generating mask 19867
# Saving mask 19867
# Generating mask 19868
# Saving mask 19868
# Generating mask 19869
# Saving mask 19869
# Generating mask 19870
# Saving mask 19870
# Generating mask 19871
# Saving mask 19871
# Generating mask 19872
# Saving mask 19872
# Generating mask 19873
# Saving mask 19873
# Generating mask 19874
# Saving mask 19874
# Generating mask 19875
# Saving mask 19875
# Generating mask 19876
# Saving mask 19876
# Generating mask 19877
# Saving mask 19877
# Generating mask 19878
# Saving mask 19878
# Generating mask 19879
# Saving mask 19879
# Generating mask 19880
# Saving mask 19880
# Generating mask 19881
# Saving mask 19881
# Generating mask 19882
# Saving mask 19882
# Generating mask 19883
# Saving mask 19883
# Generating mask 19884
# Saving mask 19884
# Generating mask 19885
# Saving mask 19885
# Generating mask 19886
# Saving mask 19886
# Generating mask 19887
# Saving mask 19887
# Generating mask 19888
# Saving mask 19888
# Generating mask 19889
# Saving mask 19889
# Generating mask 19890
# Saving mask 19890
# Generating mask 19891
# Saving mask 19891
# Generating mask 19892
# Saving mask 19892
# Generating mask 19893
# Saving mask 19893
# Generating mask 19894
# Saving mask 19894
# Generating mask 19895
# Saving mask 19895
# Generating mask 19896
# Saving mask 19896
# Generating mask 19897
# Saving mask 19897
# Generating mask 19898
# Saving mask 19898
# Generating mask 19899
# Saving mask 19899
# Generating mask 19900
# Saving mask 19900
# Generating mask 19901
# Saving mask 19901
# Generating mask 19902
# Saving mask 19902
# Generating mask 19903
# Saving mask 19903
# Generating mask 19904
# Saving mask 19904
# Generating mask 19905
# Saving mask 19905
# Generating mask 19906
# Saving mask 19906
# Generating mask 19907
# Saving mask 19907
# Generating mask 19908
# Saving mask 19908
# Generating mask 19909
# Saving mask 19909
# Generating mask 19910
# Saving mask 19910
# Generating mask 19911
# Saving mask 19911
# Generating mask 19912
# Saving mask 19912
# Generating mask 19913
# Saving mask 19913
# Generating mask 19914
# Saving mask 19914
# Generating mask 19915
# Saving mask 19915
# Generating mask 19916
# Saving mask 19916
# Generating mask 19917
# Saving mask 19917
# Generating mask 19918
# Saving mask 19918
# Generating mask 19919
# Saving mask 19919
# Generating mask 19920
# Saving mask 19920
# Generating mask 19921
# Saving mask 19921
# Generating mask 19922
# Saving mask 19922
# Generating mask 19923
# Saving mask 19923
# Generating mask 19924
# Saving mask 19924
# Generating mask 19925
# Saving mask 19925
# Generating mask 19926
# Saving mask 19926
# Generating mask 19927
# Saving mask 19927
# Generating mask 19928
# Saving mask 19928
# Generating mask 19929
# Saving mask 19929
# Generating mask 19930
# Saving mask 19930
# Generating mask 19931
# Saving mask 19931
# Generating mask 19932
# Saving mask 19932
# Generating mask 19933
# Saving mask 19933
# Generating mask 19934
# Saving mask 19934
# Generating mask 19935
# Saving mask 19935
# Generating mask 19936
# Saving mask 19936
# Generating mask 19937
# Saving mask 19937
# Generating mask 19938
# Saving mask 19938
# Generating mask 19939
# Saving mask 19939
# Generating mask 19940
# Saving mask 19940
# Generating mask 19941
# Saving mask 19941
# Generating mask 19942
# Saving mask 19942
# Generating mask 19943
# Saving mask 19943
# Generating mask 19944
# Saving mask 19944
# Generating mask 19945
# Saving mask 19945
# Generating mask 19946
# Saving mask 19946
# Generating mask 19947
# Saving mask 19947
# Generating mask 19948
# Saving mask 19948
# Generating mask 19949
# Saving mask 19949
# Generating mask 19950
# Saving mask 19950
# Generating mask 19951
# Saving mask 19951
# Generating mask 19952
# Saving mask 19952
# Generating mask 19953
# Saving mask 19953
# Generating mask 19954
# Saving mask 19954
# Generating mask 19955
# Saving mask 19955
# Generating mask 19956
# Saving mask 19956
# Generating mask 19957
# Saving mask 19957
# Generating mask 19958
# Saving mask 19958
# Generating mask 19959
# Saving mask 19959
# Generating mask 19960
# Saving mask 19960
# Generating mask 19961
# Saving mask 19961
# Generating mask 19962
# Saving mask 19962
# Generating mask 19963
# Saving mask 19963
# Generating mask 19964
# Saving mask 19964
# Generating mask 19965
# Saving mask 19965
# Generating mask 19966
# Saving mask 19966
# Generating mask 19967
# Saving mask 19967
# Generating mask 19968
# Saving mask 19968
# Generating mask 19969
# Saving mask 19969
# Generating mask 19970
# Saving mask 19970
# Generating mask 19971
# Saving mask 19971
# Generating mask 19972
# Saving mask 19972
# Generating mask 19973
# Saving mask 19973
# Generating mask 19974
# Saving mask 19974
# Generating mask 19975
# Saving mask 19975
# Generating mask 19976
# Saving mask 19976
# Generating mask 19977
# Saving mask 19977
# Generating mask 19978
# Saving mask 19978
# Generating mask 19979
# Saving mask 19979
# Generating mask 19980
# Saving mask 19980
# Generating mask 19981
# Saving mask 19981
# Generating mask 19982
# Saving mask 19982
# Generating mask 19983
# Saving mask 19983
# Generating mask 19984
# Saving mask 19984
# Generating mask 19985
# Saving mask 19985
# Generating mask 19986
# Saving mask 19986
# Generating mask 19987
# Saving mask 19987
# Generating mask 19988
# Saving mask 19988
# Generating mask 19989
# Saving mask 19989
# Generating mask 19990
# Saving mask 19990
# Generating mask 19991
# Saving mask 19991
# Generating mask 19992
# Saving mask 19992
# Generating mask 19993
# Saving mask 19993
# Generating mask 19994
# Saving mask 19994
# Generating mask 19995
# Saving mask 19995
# Generating mask 19996
# Saving mask 19996
# Generating mask 19997
# Saving mask 19997
# Generating mask 19998
# Saving mask 19998
# Generating mask 19999
# Saving mask 19999
# <Response [200]>

# %%
plt.imshow(mask, cmap='gray')

# %%
def create_dirty_images(images_dir, output_folder):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    if not os.path.exists(output_folder+"train"):
        os.makedirs(output_folder+"train")
    if not os.path.exists(output_folder+"train_mask"):
        os.makedirs(output_folder+"train_mask")    
    images = os.listdir(images_dir)
    masks = os.listdir("./test/train_dirtytrain_mask/")
    for image, mask in zip(images, masks):
        original_img = cv.imread(images_dir + image)
        binary_mask = cv.imread("./test/train_dirtytrain_mask/"+mask, cv.IMREAD_GRAYSCALE)
        print(mask)
        # plt.imshow(mask)
        plt.imshow(binary_mask, cmap='gray')
        darkening_mask_colored = cv2.cvtColor(mask, cv2.COLOR_GRAY2BGR)
        dirty_image = (original_img * darkening_mask_colored).astype(np.uint8)
        blurred_img = np.stack([gaussian(dirty_image[..., i], sigma=1) for i in range(dirty_image.shape[-1])], axis=-1)
        blurred_img = img_as_ubyte(blurred_img)
        img_dirty_final = dirty_image.copy()
        # img_dirty_final[binary_mask < 230] = blurred_img[binary_mask < 230]
        # cv.imwrite(output_folder+"train/"+image, img_dirty_final,)
        # cv.imwrite(output_folder+"train_mask/"+image+"_mask.png", binary_mask)
        # img_dirty_final = cv2.cvtColor(img_dirty_final, cv2.COLOR_BGR2RGB)

# %%
create_dirty_images("./test/train/", "./test/new_loader_test")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 create_dirty_images("./test/train/", "./test/new_loader_test")
#
# TypeError: create_dirty_images() takes 0 positional arguments but 2 were given

# %%
import cv2

# %%
def create_dirty_images(): 
    image = "./informe/images/image1.png"
    mask = "./informe/mask/mask1.png"
    original_img = cv.imread(image)
    binary_mask = cv.imread(mask, cv.IMREAD_GRAYSCALE)
    darkening_mask_colored = cv2.cvtColor(binary_mask, cv2.COLOR_GRAY2BGR)
    dirty_image = (original_img * darkening_mask_colored).astype(np.uint8)
    blurred_img = np.stack([gaussian(dirty_image[..., i], sigma=3) for i in range(dirty_image.shape[-1])], axis=-1)
    blurred_img = img_as_ubyte(blurred_img)
    img_dirty_final = dirty_image.copy()
    img_dirty_final[binary_mask < 230] = blurred_img[binary_mask < 230]
    # img_dirty_final = cv2.cvtColor(img_dirty_final, cv2.COLOR_BGR2RGB)
    # dirty_image = cv2.cvtColor(dirty_image, cv2.COLOR_BGR2RGB)
    fig, arr = plt.subplots(1, 2, figsize=(30, 5))
    arr[0].imshow(img_dirty_final)
    arr[1].imshow(dirty_image)


    cv.imwrite("./informe/image_blur.png", img_dirty_final,)
    cv.imwrite("./informe/image_binary.png", dirty_image)
    # img_dirty_final = cv2.cvtColor(img_dirty_final, cv2.COLOR_BGR2RGB)

# %%
from skimage.io import imread
from skimage.transform import resize
from skimage.util import random_noise
from skimage.morphology import dilation, disk
from skimage.filters import gaussian
from skimage import img_as_ubyte

# %%
create_dirty_images()

# %%
image = "./informe/images/image1.png"
mask = "./informe/mask/mask1.png"
original_img = cv.imread(image)
mask = cv.imread(mask)
mask_converted = mask.astype(np.float32) / 255.0
darkening_mask_colored = np.stack([mask_converted] * 3, axis=-1)
img_dirty = (img * darkening_mask_colored).astype(np.uint8)
mask_resized_binary = np.where(mask_resized > 0.9, 1, 0)
# mask_resized = np.where(mask_resized > 0.9, 1, 0)
# Convert skimage mask to uint8 if needed
mask_resized_uint8 = img_as_ubyte(mask_resized > 0)  # Ensure binary mask is uint8

# Step 1: Dilate the mask to expand the dirt spots (10-pixel radius)
# selem = disk(10)  # Structuring element of radius ~10
# mask_dilated = dilation(mask_resized, selem).astype(np.uint8)  # Skimage dilation

# Step 2: Apply Gaussian blur to the expanded region
if img_dirty.ndim == 3:  # Check if it's a color image
    blurred_img = np.stack([gaussian(img_dirty_resized[..., i], sigma=self.sigma) for i in range(img_dirty_resized.shape[-1])], axis=-1)
